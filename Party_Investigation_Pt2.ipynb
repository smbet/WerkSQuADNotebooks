# %% [markdown]
# This notebook is wayyyyy toooooo lonnnnnnggggggg

# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import astropy.units as u
import astropy.constants as co
import astropy.cosmology
import astropy.stats.biweight as biw
import connectivity
import os

from glob import glob

from os.path import expanduser

import matplotlib.pylab as plt
from matplotlib.colors import ListedColormap
from astropy.coordinates import SkyCoord
from astropy.table import Table

# This is necessary to shut python up while running the fourth cell.
import warnings
warnings.filterwarnings("ignore")

# %%
cosm = astropy.cosmology.Planck15

# %%
home = expanduser('~')
path = os.path.join(home,'Dropbox','**','legit_final_table.csv')
filepath = glob(path, recursive=True)
gal_info = pd.read_csv(filepath[0], index_col=None)

gal_info.rename(columns={'OBJECT_x': 'OBJECT'}, inplace=True)
gal_info.rename(columns={'specfile_x': 'specfile'}, inplace=True)
gal_info.rename(columns={'gal_ra_x': 'gal_ra'}, inplace=True)
gal_info.rename(columns={'gal_dec_x': 'gal_dec'}, inplace=True)

# %% [markdown]
# Making a list of which galaxies are within the linking length in angular dist and within $1000 \; \frac{km}{s}$ in z/velocity space.

# %%
have_friends = []
for ii in range(len(gal_info)):
    # just compare galaxies around same QSO
    #small_info = gal_info[gal_info['id']==gal_info.OBJECT.loc[ii]]
    small_info = gal_info # :(
    c1 = SkyCoord(small_info.gal_ra.loc[ii]*u.deg, small_info.gal_dec.loc[ii]*u.deg)
    c2 = SkyCoord(small_info.gal_ra*u.deg, small_info.gal_dec*u.deg)
    sep = c1.separation(c2)
    friends = np.where(
        (((cosm.angular_diameter_distance(small_info['z'].loc[ii])*sep.radian).value)<(0.34*(1+1.4*np.arctan(small_info['z'].loc[ii]/0.09))))
        &
        (((cosm.scale_factor(small_info['z'].loc[ii])*np.abs(small_info['z']-small_info['z'].loc[ii])*co.c.to('km/s').value)<1000)
        &
        (small_info['z'].index != ii)
        )
    )
    if len(friends[0]) > 0:
        have_friends.append([ii,np.ravel(friends)])

# %% [markdown]
# Part where we find friends of friends and group them together:

# %%
have_friends = np.array(have_friends)

# %%
connectedness = connectivity.ConnectedComponents(np.arange(len(gal_info)))

# %%
for ii,ijs in have_friends:
    for ij in ijs:
        connectedness.add_edge(ii,ij)

# %%
inds,grps=connectedness.get_all_roots(reindex_root_values=True)

# %%
gal_info['friends_group'] = grps

# %% [markdown]
# Part where we find lots of interesting things about our friend groups (just the bigger ones to start with):

# %%
list_o_lists = []
id_list = []
for ii in range(len(gal_info)):
    bffs = gal_info.query('friends_group=='+str(ii))
    # set this to 5 for the large groups, 3 for all of the small ones too
    if len(bffs)>=5:
        zloc = biw.biweight_location(bffs.z)
        ra_loc = biw.biweight_location(bffs.gal_ra)
        dec_loc = biw.biweight_location(bffs.gal_dec)
        member_ids = bffs.id
        membermorphology = bffs.gal_type
        # do I need to worry about the scale factor here?
        vel_disp = biw.biweight_scale(bffs.z)*co.c.to('km/s')
        
        # cluster masses section:
        seplist=[]
        for ii in bffs.T:
            c1 = SkyCoord(bffs.gal_ra.loc[ii]*u.deg, bffs.gal_dec.loc[ii]*u.deg)
            c2 = SkyCoord(bffs.gal_ra*u.deg, bffs.gal_dec*u.deg)
            sep = c1.separation(c2)
            seplist.append(np.max(sep.radian))
        rad = np.max(seplist)*cosm.angular_diameter_distance(biw.biweight_location(bffs.z))/2
        # if I'm misrepresenting the virial theorem here blame Jess' slides
        mass = (5/3)*rad*(vel_disp**2)/co.G
        logmass = np.log10(mass.to('M_sun').value)
        
        QSO = bffs.OBJECT.loc[ii]
        
        # info about location of cluster's most massive member:
        biggest_boi_idx = bffs.mstars.idxmax()
        biggest_boi = bffs.loc[biggest_boi_idx]
        # separation betwixt the center and the biggest boi:
        grp_cent = SkyCoord(ra_loc*u.deg, dec_loc*u.deg)
        biggest_loc = SkyCoord(biggest_boi.gal_ra*u.deg,biggest_boi.gal_dec*u.deg)
        center_diff = grp_cent.separation(biggest_loc)
        center_diff_mpc = center_diff.radian*cosm.angular_diameter_distance(zloc)
        list_o_lists.append([len(bffs),QSO,zloc,biggest_boi.z,vel_disp,rad,logmass,ra_loc,dec_loc,biggest_boi.gal_ra,biggest_boi.gal_dec,center_diff_mpc,member_ids,membermorphology,biggest_boi.gal_type])

# %%
listkeys = ['party_size','QSO','redshift_guess','biggest_boi_z','vel_disp','radius','logmass','center_ra','center_dec','biggest_boi_gal_ra','biggest_boi_gal_dec','center_diff_mpc','member_ids','morphology','biggest_boi_morphology']

# %%
big_dtf = pd.DataFrame(list_o_lists,columns=listkeys)

# %%
big_dtf
# Out:
#     party_size         QSO  redshift_guess  biggest_boi_z  \
# 0            5  J0843+4117        0.541737       0.539816
# 1            8  J0843+4117        0.807485       0.807099
# 2            5  J0914+2823        0.510012       0.509319
# 3            5  J0935+0204        0.225748       0.225570
# 4            5  J0935+0204        0.424802       0.424721
# 5            5  J1001+5944        0.374205       0.375555
# 6            7  J1001+5944        0.282140       0.281961
# 7            6  J1001+5944        0.304297       0.305044
# 8           15  J1016+4706        0.165925       0.165040
# 9           10  J1112+3539        0.449350       0.449440
# 10           6  J1133+0327        0.236423       0.236190
# 11           6  J1134+2555        0.499933       0.502292
# 12          10  J1419+4207        0.523167       0.525289
# 13           7  J1419+4207        0.425818       0.429390
# 14           8  J1437+5045        0.737583       0.738240
# 15           7  J1437+5045        0.770344       0.770453
# 16           5  J1553+3548        0.514815       0.515695
#
#                      vel_disp                   radius    logmass   center_ra  \
# 0   360.04584297820315 km / s    0.722004609960654 Mpc  13.559543  130.941802
# 1    503.8134162083585 km / s   0.8386772935155622 Mpc  13.916422  130.974259
# 2   150.76630517177458 km / s   0.7520359746396579 Mpc  12.821135  138.705930
# 3   358.71761577068156 km / s   0.4025263840445176 Mpc  13.302587  143.803112
# 4   136.63079844809084 km / s  0.30944937229167885 Mpc  12.349974  143.840164
# 5   51.016126529871144 km / s   0.5688901390254302 Mpc  11.758731  150.219894
# 6   227.87300270008683 km / s   0.5353871986951582 Mpc  13.032341  150.301684
# 7    240.0750518356186 km / s  0.26566115918382893 Mpc  12.773310  150.260730
# 8    726.2560273933645 km / s  0.41544731779837357 Mpc  13.928983  154.097618
# 9    652.1737772900967 km / s  0.43644447797189273 Mpc  13.856943  165.014694
# 10  202.15525003583167 km / s  0.08966020454289765 Mpc  12.152257  165.014694
# 11   615.8994473711278 km / s    0.421390098611543 Mpc  13.791992  173.757200
# 12   448.4756817567214 km / s   0.8004768097057685 Mpc  13.795114  214.774654
# 13   773.2010386593704 km / s   1.0220634595991092 Mpc  14.374350  214.803681
# 14   459.6277561104449 km / s   1.1709008250134947 Mpc  13.981620  219.366339
# 15  228.33836062007572 km / s   1.0825178373201987 Mpc  13.339880  219.389200
# 16   244.6061982685603 km / s   0.5849852395413537 Mpc  13.132367  238.258513
#
#     center_dec  biggest_boi_gal_ra  biggest_boi_gal_dec  \
# 0    41.319185          130.974518            41.320671
# 1    41.286176          130.974472            41.283920
# 2    28.389861          138.706863            28.411850
# 3     2.087740          143.811066             2.089780
# 4     2.078813          143.845688             2.072880
# 5    59.734655          150.167892            59.747490
# 6    59.736018          150.301437            59.760860
# 7    59.723170          150.258621            59.717300
# 8    47.098664          154.098694            47.079948
# 9    35.661318          165.014694            35.680431
# 10    3.449726          165.014694             3.442030
# 11   25.920128          173.746643            25.911961
# 12   42.141278          214.781998            42.169891
# 13   42.120880          214.835998            42.091030
# 14   50.779714          219.413590            50.786930
# 15   50.757581          219.409698            50.760811
# 16   35.815565          238.263519            35.784729
#
#             center_diff_mpc  \
# 0    0.5807582189335815 Mpc
# 1   0.06307156672222673 Mpc
# 2    0.5033450096284552 Mpc
# 3   0.11043159248548431 Mpc
# 4   0.16748516463364543 Mpc
# 5    0.5582834513509644 Mpc
# 6    0.3936250497089242 Mpc
# 7    0.0996189150353009 Mpc
# 8   0.19775972735461889 Mpc
# 9   0.40803067182833663 Mpc
# 10  0.10722418386857346 Mpc
# 11  0.28351639249895144 Mpc
# 12   0.6751293903305702 Mpc
# 13   0.7923438192774475 Mpc
# 14   0.8301951461681577 Mpc
# 15  0.36674485054528266 Mpc
# 16   0.7149615176251402 Mpc
#
#                                            member_ids  \
# 0   57     J084340.92+411951.6._05
# 61     J084342....
# 1   59     J084341.89+411628.9._04
# 73     J084345....
# 2   136    J091435.68+282229.9._01
# 155    J091446....
# 3   168    J093510.25+020630.5._09
# 170    J093511....
# 4   186    J093518.97+020500.9._09
# 191    J093521....
# 5   224    J100040.30+594451.0._12
# 227    J100047....
# 6   235    J100054.87+594436.7._10
# 241    J100100....
# 7   237    J100057.19+594233.8._11
# 239    J100100....
# 8   276    J101614.74+470515.3._13
# 278    J101614....
# 9   419    J111231.19+354049.6._19
# 421    J111231....
# 10  450    J113315.65+032647.5._05
# 453    J113321....
# 11  502    J113459.07+255356.1._05
# 503    J113459....
# 12  581    J141859.98+420618.5._06
# 594    J141903....
# 13  587    J141901.21+421010.1._05
# 611    J141908....
# 14  645    J143708.95+504621.9._10
# 647    J143713....
# 15  676    J143727.55+504620.9._08
# 678    J143728....
# 16  709    J155257.05+354920.1._13
# 717    J155259....
#
#                                            morphology biggest_boi_morphology
# 0   57       b'SF'
# 61       b'SF'
# 75     b'SF+E'
# 8...                  b'SF'
# 1   59     b'SF+E'
# 73     b'SF+E'
# 78       b'SF'
# 9...                  b'SF'
# 2   136    b'SF+E'
# 155      b'SF'
# 161      b'SF'
# 1...                  b'SF'
# 3   168      b'SF'
# 170    b'SF+E'
# 172      b'SF'
# 1...                  b'SF'
# 4   186    b'SF'
# 191    b'SF'
# 192    b'SF'
# 195    ...                  b'SF'
# 5   224      b'SF'
# 227      b'SF'
# 228      b'SF'
# 2...                  b'SF'
# 6   235    b'SF+E'
# 241      b'SF'
# 257    b'SF+E'
# 2...                b'SF+E'
# 7   237    b'SF+E'
# 239    b'SF+E'
# 243      b'SF'
# 2...                  b'SF'
# 8   276    b'SF+E'
# 278    b'SF+E'
# 282      b'SF'
# 2...                  b'SF'
# 9   419    b'SF+E'
# 421    b'SF+E'
# 423    b'SF+E'
# 4...                b'SF+E'
# 10  450    b'SF+E'
# 453    b'SF+E'
# 454    b'SF+E'
# 4...                b'SF+E'
# 11  502    b'SF+E'
# 503    b'SF+E'
# 508      b'SF'
# 5...                b'SF+E'
# 12  581      b'SF'
# 594      b'SF'
# 595      b'SF'
# 5...                  b'SF'
# 13  587      b'SF'
# 611      b'SF'
# 624    b'SF+E'
# 6...                b'SF+E'
# 14  645      b'SF'
# 647    b'SF+E'
# 662      b'SF'
# 6...                b'SF+E'
# 15  676    b'SF+E'
# 678      b'SF'
# 685      b'SF'
# 6...                b'SF+E'
# 16  709    b'SF+E'
# 717    b'SF+E'
# 724      b'SF'
# 7...                b'SF+E'

# %% [markdown]
# ### things to look at:
#
# look for isolated hosts (next smallest 1/3 in stellar mass)
# look at angles and see what's up, use astropy position angle
# from that, absorption! Could use distance to host and galaxy, or distance to host and position angle to galaxy
# hosts don't necessarily need to be isolated for abs. part

# %%
# let's see what Kirill got:

party_directory = pd.read_csv('./py_files/candidate_groups.txt')

# %%
party_directory
# Out:
#             QSO  size_guess  redshift_guess
# 0   J0843+4117            7        0.542320
# 1   J0843+4117            6        0.807626
# 2   J1001+5944            8        0.282191
# 3   J1001+5944            7        0.304520
# 4   J1016+4706           22        0.166070
# 5   J1112+3539           21        0.448303
# 6   J1133+0327           10        0.236273
# 7   J1133+0327            6        0.349436
# 8   J1134+2555            7        0.426730
# 9   J1134+2555            9        0.501406
# 10  J1419+4207           12        0.523247
# 11  J1437+5045            7        0.664346

# %% [markdown]
# yeah that's not quite the same oh well

# %% [markdown]
# ### Conformity of larger groups:

# %%
for ii in range(len(big_dtf)):
    print(big_dtf.morphology[ii])
# Out:
# 57       b'SF'
# 61       b'SF'
# 75     b'SF+E'
# 86       b'SF'
# 103      b'SF'
# Name: gal_type, dtype: object
# 59     b'SF+E'
# 73     b'SF+E'
# 78       b'SF'
# 99       b'SF'
# 102      b'SF'
# 104    b'SF+E'
# 106      b'SF'
# 108    b'SF+E'
# Name: gal_type, dtype: object
# 136    b'SF+E'
# 155      b'SF'
# 161      b'SF'
# 162      b'SF'
# 164    b'SF+E'
# Name: gal_type, dtype: object
# 168      b'SF'
# 170    b'SF+E'
# 172      b'SF'
# 174      b'SF'
# 177      b'SF'
# Name: gal_type, dtype: object
# 186    b'SF'
# 191    b'SF'
# 192    b'SF'
# 195    b'SF'
# 199    b'SF'
# Name: gal_type, dtype: object
# 224      b'SF'
# 227      b'SF'
# 228      b'SF'
# 250    b'SF+E'
# 252      b'SF'
# Name: gal_type, dtype: object
# 235    b'SF+E'
# 241      b'SF'
# 257    b'SF+E'
# 261    b'SF+E'
# 263    b'SF+E'
# 265    b'SF+E'
# 270      b'SF'
# Name: gal_type, dtype: object
# 237    b'SF+E'
# 239    b'SF+E'
# 243      b'SF'
# 245      b'SF'
# 246      b'SF'
# 251      b'SF'
# Name: gal_type, dtype: object
# 276    b'SF+E'
# 278    b'SF+E'
# 282      b'SF'
# 285      b'SF'
# 286      b'SF'
# 287    b'SF+E'
# 292      b'SF'
# 294    b'SF+E'
# 300      b'SF'
# 301      b'SF'
# 306      b'SF'
# 315      b'SF'
# 319      b'SF'
# 325      b'SF'
# 326      b'SF'
# Name: gal_type, dtype: object
# 419    b'SF+E'
# 421    b'SF+E'
# 423    b'SF+E'
# 431      b'SF'
# 434      b'SF'
# 438      b'SF'
# 440    b'SF+E'
# 443    b'SF+E'
# 445    b'SF+E'
# 449      b'SF'
# Name: gal_type, dtype: object
# 450    b'SF+E'
# 453    b'SF+E'
# 454    b'SF+E'
# 459      b'SF'
# 460    b'SF+E'
# 462    b'SF+E'
# Name: gal_type, dtype: object
# 502    b'SF+E'
# 503    b'SF+E'
# 508      b'SF'
# 512    b'SF+E'
# 513      b'SF'
# 520      b'SF'
# Name: gal_type, dtype: object
# 581      b'SF'
# 594      b'SF'
# 595      b'SF'
# 597      b'SF'
# 599    b'SF+E'
# 600    b'SF+E'
# 607      b'SF'
# 612    b'SF+E'
# 617      b'SF'
# 619      b'SF'
# Name: gal_type, dtype: object
# 587      b'SF'
# 611      b'SF'
# 624    b'SF+E'
# 627      b'SF'
# 631      b'SF'
# 637    b'SF+E'
# 638      b'SF'
# Name: gal_type, dtype: object
# 645      b'SF'
# 647    b'SF+E'
# 662      b'SF'
# 667      b'SF'
# 687    b'SF+E'
# 695    b'SF+E'
# 700    b'SF+E'
# 702      b'SF'
# Name: gal_type, dtype: object
# 676    b'SF+E'
# 678      b'SF'
# 685      b'SF'
# 694    b'SF+E'
# 696    b'SF+E'
# 697      b'SF'
# 699    b'SF+E'
# Name: gal_type, dtype: object
# 709    b'SF+E'
# 717    b'SF+E'
# 724      b'SF'
# 725    b'SF+E'
# 733    b'SF+E'
# Name: gal_type, dtype: object

# %% [markdown]
# ### Now for the wee little groups!

# %%
list_o_lists = []
id_list = []
for ii in range(len(gal_info)):
    bffs = gal_info.query('friends_group=='+str(ii))
    # set this to 5 for the large groups, 3 for all of the small ones too
    if len(bffs)>=3:
        zloc = biw.biweight_location(bffs.z)
        ra_loc = biw.biweight_location(bffs.gal_ra)
        dec_loc = biw.biweight_location(bffs.gal_dec)
        member_ids = bffs.id
        membermorphology = bffs.gal_type
        memberstellarmasses = bffs.mstars
        vel_disp = biw.biweight_scale(bffs.z)*co.c.to('km/s')
        
        # cluster masses section:
        seplist=[]
        for ii in bffs.T:
            c1 = SkyCoord(bffs.gal_ra.loc[ii]*u.deg, bffs.gal_dec.loc[ii]*u.deg)
            c2 = SkyCoord(bffs.gal_ra*u.deg, bffs.gal_dec*u.deg)
            sep = c1.separation(c2)
            seplist.append(np.max(sep.radian))
        rad = np.max(seplist)*cosm.angular_diameter_distance(biw.biweight_location(bffs.z))/2
        # if I'm misrepresenting the virial theorem here blame Jess' slides
        mass = (5/3)*rad*(vel_disp**2)/co.G
        logmass = np.log10(mass.to('M_sun').value)
        
        QSO = bffs.OBJECT.loc[ii]
        
        # smallest impact parameter w.r.t. QSO:
        minpact_parameter = bffs.rho_impact.nsmallest(1)
        # info about location of cluster's most massive member:
        biggest_boi_idx = bffs.mstars.idxmax()
        biggest_boi = bffs.loc[biggest_boi_idx]
        # separation betwixt the center and the biggest boi:
        grp_cent = SkyCoord(ra_loc*u.deg, dec_loc*u.deg)
        biggest_loc = SkyCoord(biggest_boi.gal_ra*u.deg,biggest_boi.gal_dec*u.deg)
        center_diff = grp_cent.separation(biggest_loc)
        center_diff_mpc = center_diff.radian*cosm.angular_diameter_distance(zloc)
        # impact parameter btwn center & QSO:
        QSOloc = SkyCoord(bffs.RA_QSO.loc[ii]*u.deg,bffs.DEC_QSO.loc[ii]*u.deg)
        center_QSO = grp_cent.separation(QSOloc)
        center_QSO_rho = center_QSO.radian*cosm.angular_diameter_distance(zloc).value
        list_o_lists.append([len(bffs),QSO,zloc,biggest_boi.z,vel_disp,rad,logmass,ra_loc,dec_loc,biggest_boi.gal_ra,biggest_boi.gal_dec,center_diff_mpc,member_ids,membermorphology,biggest_boi.gal_type,memberstellarmasses,minpact_parameter,center_QSO_rho])

# %%
listkeys = ['party_size','QSO','redshift_guess','biggest_boi_z','vel_disp','radius','logmass','center_ra','center_dec','biggest_boi_gal_ra','biggest_boi_gal_dec','center_diff_mpc','member_ids','morphology','biggestgaltype','stellar_masses','QSOrho_min','center_QSO_rho']

# %%
wee_little_groups = pd.DataFrame(list_o_lists,columns=listkeys)

# %%
wee_little_groups
# Out:
#     party_size         QSO  redshift_guess  biggest_boi_z  \
# 0            3  J0226+0015        0.352969       0.349424
# 1            3  J0226+0015        0.297729       0.297832
# 2            3  J0809+4619        0.520972       0.520903
# 3            3  J0809+4619        0.532704       0.530117
# 4            5  J0843+4117        0.541737       0.539816
# 5            8  J0843+4117        0.807485       0.807099
# 6            3  J0843+4117        0.593428       0.593416
# 7            4  J0843+4117        0.579206       0.580030
# 8            4  J0843+4117        0.300782       0.304114
# 9            3  J0843+4117        0.455167       0.454648
# 10           4  J0843+4117        0.591607       0.590281
# 11           5  J0914+2823        0.510012       0.509319
# 12           4  J0914+2823        0.600128       0.599377
# 13           3  J0914+2823        0.227620       0.228207
# 14           3  J0914+2823        0.310807       0.311144
# 15           5  J0935+0204        0.225748       0.225570
# 16           3  J0935+0204        0.353180       0.349514
# 17           5  J0935+0204        0.424802       0.424721
# 18           3  J0935+0204        0.262358       0.262356
# 19           3  J0943+0531        0.352826       0.349870
# 20           4  J0943+0531        0.548617       0.548817
# 21           5  J1001+5944        0.374205       0.375555
# 22           7  J1001+5944        0.282140       0.281961
# 23           6  J1001+5944        0.304297       0.305044
# 24          15  J1016+4706        0.165925       0.165040
# 25           4  J1016+4706        0.485172       0.486410
# 26           3  J1016+4706        0.671667       0.671665
# 27           4  J1016+4706        0.473917       0.476064
# 28           3  J1016+4706        0.725309       0.726890
# 29           3  J1022+0132        0.306354       0.306360
# ..         ...         ...             ...            ...
# 31           4  J1022+0132        0.478885       0.478865
# 32           3  J1022+0132        0.778404       0.778528
# 33           3  J1059+2517        0.252350       0.252359
# 34          10  J1112+3539        0.449350       0.449440
# 35           6  J1133+0327        0.236423       0.236190
# 36           3  J1133+0327        0.467718       0.467685
# 37           3  J1133+0327        0.246386       0.246718
# 38           4  J1134+2555        0.425056       0.429352
# 39           3  J1134+2555        0.682333       0.686190
# 40           6  J1134+2555        0.499933       0.502292
# 41           3  J1233-0031        0.318701       0.318743
# 42           4  J1233-0031        0.429621       0.429505
# 43           4  J1241+5721        0.457328       0.456986
# 44           3  J1419+4207        0.804639       0.804798
# 45          10  J1419+4207        0.523167       0.525289
# 46           3  J1419+4207        0.451054       0.450542
# 47           7  J1419+4207        0.425818       0.429390
# 48           3  J1419+4207        0.844714       0.845320
# 49           3  J1437+5045        0.129863       0.129806
# 50           8  J1437+5045        0.737583       0.738240
# 51           3  J1437+5045        0.507022       0.506984
# 52           3  J1437+5045        0.568278       0.568027
# 53           4  J1437+5045        0.368861       0.368891
# 54           7  J1437+5045        0.770344       0.770453
# 55           3  J1437+5045        0.662283       0.665170
# 56           5  J1553+3548        0.514815       0.515695
# 57           3  J1553+3548        0.638321       0.637736
# 58           3  J1553+3548        0.341723       0.341716
# 59           4  J1553+3548        0.217451       0.217138
# 60           3  J1555+3628        0.473317       0.473284
#
#                      vel_disp                   radius    logmass   center_ra  \
# 0   434.27875527748006 km / s  0.47554728663794493 Mpc  13.541019   36.550684
# 1    82.10966884351586 km / s   0.5454572807064169 Mpc  12.153837   36.534892
# 2   170.96243529961782 km / s   0.4460492822060432 Mpc  12.703472  122.302953
# 3    64.25117503448554 km / s   0.2425109703073517 Mpc  11.588781  122.316879
# 4   360.04584297820315 km / s    0.722004609960654 Mpc  13.559543  130.941802
# 5    503.8134162083585 km / s   0.8386772935155622 Mpc  13.916422  130.974259
# 6    587.4728056954765 km / s   0.4896173058758222 Mpc  13.816120  130.961451
# 7     741.130979407261 km / s   0.6160718164183764 Mpc  14.117709  130.958811
# 8    774.4812148770999 km / s  0.36306714026127324 Mpc  13.926296  130.978158
# 9   100.59593301093065 km / s   0.2937173137685766 Mpc  12.061378  130.960342
# 10   310.0460245915281 km / s   0.3761479637639749 Mpc  13.146499  130.984439
# 11  150.76630517177458 km / s   0.7520359746396579 Mpc  12.821135  138.705930
# 12   210.4741084339208 km / s   0.4752470294288141 Mpc  12.911604  138.652848
# 13  240.27501987336456 km / s    0.251752369433876 Mpc  12.750678  138.694743
# 14   561.4205251140576 km / s  0.44549509983645014 Mpc  13.735707  138.688157
# 15  358.71761577068156 km / s   0.4025263840445176 Mpc  13.302587  143.803112
# 16   822.0843914831577 km / s   0.3401254094698518 Mpc  13.949760  143.823312
# 17  136.63079844809084 km / s  0.30944937229167885 Mpc  12.349974  143.840164
# 18  0.9201273020458339 km / s  0.15471800895647564 Mpc   7.705524  143.846282
# 19   655.9707824671318 km / s   0.2454700801315825 Mpc  13.612055  145.877258
# 20  60.440454606204995 km / s  0.39107765523775706 Mpc  11.743206  145.892163
# 21  51.016126529871144 km / s   0.5688901390254302 Mpc  11.758731  150.219894
# 22  227.87300270008683 km / s   0.5353871986951582 Mpc  13.032341  150.301684
# 23   240.0750518356186 km / s  0.26566115918382893 Mpc  12.773310  150.260730
# 24   726.2560273933645 km / s  0.41544731779837357 Mpc  13.928983  154.097618
# 25  388.28196156311554 km / s   0.7991384124444748 Mpc  13.669204  154.093592
# 26   5.027139909605434 km / s   0.7483007799189905 Mpc   9.865006  154.120364
# 27  455.71223330553465 km / s    0.440068504891036 Mpc  13.549189  154.105707
# 28   384.4577974819056 km / s   0.5168663501593678 Mpc  13.471363  154.103493
# 29  49.823274227083125 km / s  0.20176510050950291 Mpc  11.287998  155.560027
# ..                        ...                      ...        ...         ...
# 31   96.22351642437532 km / s   0.4256346803900126 Mpc  12.183887  155.594120
# 32  211.36513504003636 km / s  0.32625040460533994 Mpc  12.751905  155.604510
# 33  132.99019217487657 km / s  0.18648443087653868 Mpc  12.106569  165.011136
# 34   652.1737772900967 km / s  0.43644447797189273 Mpc  13.856943  165.014694
# 35  202.15525003583167 km / s  0.08966020454289765 Mpc  12.152257  165.014694
# 36  17.193235872562784 km / s  0.37628639216676374 Mpc  10.634521  165.014694
# 37   76.34302585189234 km / s  0.26090441662391234 Mpc  11.770308  165.014694
# 38   910.3030196784903 km / s  0.08806793044548428 Mpc  13.451477  165.014694
# 39   37.14685365127767 km / s  0.07194602335718978 Mpc  10.585139  165.014694
# 40   615.8994473711278 km / s    0.421390098611543 Mpc  13.791992  173.757200
# 41   88.59612099776476 km / s  0.08631185228034917 Mpc  11.419188  188.263055
# 42   61.12559304011862 km / s  0.30678702056675555 Mpc  11.647571  188.276403
# 43  409.52890472261953 km / s  0.47295867309821066 Mpc  13.487680  190.458348
# 44   78.79438613759665 km / s    0.500663331857725 Mpc  12.080824  214.760092
# 45   448.4756817567214 km / s   0.8004768097057685 Mpc  13.795114  214.774654
# 46   547.3745465285758 km / s   0.5152001720735138 Mpc  13.776833  214.780044
# 47   773.2010386593704 km / s   1.0220634595991092 Mpc  14.374350  214.803681
# 48   663.2489729066789 km / s    0.467671855190145 Mpc  13.901582  214.792490
# 49  30.811119942886368 km / s   0.4409059561591224 Mpc  11.210049  219.351719
# 50   459.6277561104449 km / s   1.1709008250134947 Mpc  13.981620  219.366339
# 51  20.137643239144477 km / s  0.44537453376787595 Mpc  10.845030  219.324709
# 52  453.73883226033576 km / s  0.20575947679303447 Mpc  13.215259  219.334858
# 53  128.01974798504548 km / s   0.5382540678603409 Mpc  12.533829  219.369060
# 54  228.33836062007572 km / s   1.0825178373201987 Mpc  13.339880  219.389200
# 55                 0.0 km / s  0.29146352500080314 Mpc       -inf  219.392225
# 56   244.6061982685603 km / s   0.5849852395413537 Mpc  13.132367  238.258513
# 57  230.58059677124402 km / s  0.47869182569595153 Mpc  12.993989  238.283400
# 58  3.3539954627102717 km / s  0.08672124371833087 Mpc   8.577538  238.247110
# 59   85.92073189919182 km / s  0.16489000246002436 Mpc  11.673678  238.274119
# 60   16.61013805659391 km / s  0.38276978095884173 Mpc  10.611972  238.749078
#
#     center_dec  biggest_boi_gal_ra  biggest_boi_gal_dec  \
# 0     0.249508           36.550751             0.251680
# 1     0.259185           36.510059             0.260170
# 2    46.331768          122.327316            46.334530
# 3    46.342665          122.326057            46.326328
# 4    41.319185          130.974518            41.320671
# 5    41.286176          130.974472            41.283920
# 6    41.332694          130.936050            41.334000
# 7    41.305138          130.938828            41.329262
# 8    41.284091          130.975021            41.275631
# 9    41.307174          130.962006            41.318649
# 10   41.277902          130.960251            41.273190
# 11   28.389861          138.706863            28.411850
# 12   28.389869          138.656982            28.384680
# 13   28.413870          138.675736            28.414169
# 14   28.386134          138.689453            28.385309
# 15    2.087740          143.811066             2.089780
# 16    2.086358          143.810104             2.082890
# 17    2.078813          143.845688             2.072880
# 18    2.084222          143.846161             2.084710
# 19    5.530814          145.862518             5.543740
# 20    5.512995          145.896805             5.500990
# 21   59.734655          150.167892            59.747490
# 22   59.736018          150.301437            59.760860
# 23   59.723170          150.258621            59.717300
# 24   47.098664          154.098694            47.079948
# 25   47.091706          154.061493            47.089951
# 26   47.100586          154.071228            47.100231
# 27   47.130616          154.127747            47.146400
# 28   47.125184          154.107437            47.121010
# 29    1.518050          155.560059             1.518240
# ..         ...                 ...                  ...
# 31    1.527781          155.593658             1.494020
# 32    1.494220          155.606110             1.495270
# 33   25.246529          164.992950            25.228970
# 34   35.661318          165.014694            35.680431
# 35    3.449726          165.014694             3.442030
# 36    3.455419          165.014694             3.453310
# 37    3.444143          165.014694             3.421860
# 38   25.922882          165.014694            25.930901
# 39   25.905016          165.014694            25.904989
# 40   25.920128          173.746643            25.911961
# 41   -0.527836          188.262955            -0.527430
# 42   -0.543167          188.295471            -0.552460
# 43   57.341748          190.481827            57.326981
# 44   42.120558          214.740555            42.119709
# 45   42.141278          214.781998            42.169891
# 46   42.126707          214.778671            42.152611
# 47   42.120880          214.835998            42.091030
# 48   42.133696          214.789032            42.133171
# 49   50.763601          219.354141            50.735260
# 50   50.779714          219.413590            50.786930
# 51   50.764800          219.323227            50.766079
# 52   50.758727          219.329620            50.748230
# 53   50.778487          219.332108            50.747459
# 54   50.757581          219.409698            50.760811
# 55   50.778816          219.391067            50.788361
# 56   35.815565          238.263519            35.784729
# 57   35.780123          238.282547            35.780510
# 58   35.783810          238.250778            35.786800
# 59   35.807291          238.279831            35.806999
# 60   36.464416          238.778564            36.448349
#
#               center_diff_mpc  \
# 0    0.040052623315028735 Mpc
# 1     0.40884518542015885 Mpc
# 2      0.3942891142330133 Mpc
# 3      0.4099305197415455 Mpc
# 4      0.5807582189335815 Mpc
# 5     0.06307156672222673 Mpc
# 6       0.471335122535602 Mpc
# 7      0.6925436901812984 Mpc
# 8     0.14549831498045593 Mpc
# 9     0.24820588956443937 Mpc
# 10     0.4623393372398707 Mpc
# 11     0.5033450096284552 Mpc
# 12    0.15706069860002936 Mpc
# 13    0.22641968877730564 Mpc
# 14   0.023841491589075694 Mpc
# 15    0.11043159248548431 Mpc
# 16     0.2516893774364515 Mpc
# 17    0.16748516463364543 Mpc
# 18  0.0075589319581334385 Mpc
# 19     0.3603675203576696 Mpc
# 20    0.30539794642643087 Mpc
# 21     0.5582834513509644 Mpc
# 22     0.3936250497089242 Mpc
# 23     0.0996189150353009 Mpc
# 24    0.19775972735461889 Mpc
# 25     0.4883812035564697 Mpc
# 26     0.8708413091876711 Mpc
# 27     0.4787481383519877 Mpc
# 28    0.13321061361105524 Mpc
# 29  0.0032222435335531848 Mpc
# ..                        ...
# 31      0.746806925710699 Mpc
# 32   0.052689307329322935 Mpc
# 33    0.35182302846648783 Mpc
# 34    0.40803067182833663 Mpc
# 35    0.10722418386857346 Mpc
# 36    0.04603875510666545 Mpc
# 37     0.3201417181443799 Mpc
# 38    0.16576636960396396 Mpc
# 39  0.0006937468181190323 Mpc
# 40    0.28351639249895144 Mpc
# 41   0.007207764503122968 Mpc
# 42      0.441247052631416 Mpc
# 43    0.41955325250387976 Mpc
# 44    0.40440868833504784 Mpc
# 45     0.6751293903305702 Mpc
# 46     0.5545832071215141 Mpc
# 47     0.7923438192774475 Mpc
# 48    0.07408164431484704 Mpc
# 49    0.24422837856685295 Mpc
# 50     0.8301951461681577 Mpc
# 51    0.03616082384349955 Mpc
# 52     0.2658798967610465 Mpc
# 53     0.7365668698560558 Mpc
# 54    0.36674485054528266 Mpc
# 55    0.24776421649996064 Mpc
# 56     0.7149615176251402 Mpc
# 57    0.02019105624423812 Mpc
# 58    0.07615675168814216 Mpc
# 59    0.06070390516104942 Mpc
# 60       0.62954707824123 Mpc
#
#                                            member_ids  \
# 0   0     J022601.51+001532.5._03
# 10    J022612.15...
# 1   1     J022602.41+001536.6._01
# 3     J022607.08...
# 2   30    J080905.28+461944.8._01
# 39    J080913.54...
# 3   40    J080913.68+462032.5._04
# 44    J080916.16...
# 4   57     J084340.92+411951.6._05
# 61     J084342....
# 5   59     J084341.89+411628.9._04
# 73     J084345....
# 6   69     J084344.65+412002.4._05
# 90     J084350....
# 7   74     J084345.32+411945.3._04
# 84     J084348....
# 8   79     J084346.79+411735.0._06
# 105    J084354....
# 9   88     J084349.68+411820.3._06
# 93     J084350....
# 10  91     J084350.46+411623.5._04
# 109    J084354....
# 11  136    J091435.68+282229.9._01
# 155    J091446....
# 12  137    J091436.16+282334.9._02
# 138    J091436....
# 13  149    J091442.18+282451.0._02
# 153    J091446....
# 14  150    J091442.85+282231.7._01
# 152    J091445....
# 15  168    J093510.25+020630.5._09
# 170    J093511....
# 16  176    J093514.43+020458.4._08
# 181    J093516....
# 17  186    J093518.97+020500.9._09
# 191    J093521....
# 18  187    J093519.30+020445.0._09
# 196    J093523....
# 19  207    J094327.00+053237.5._02
# 209    J094330....
# 20  213    J094332.32+053152.3._03
# 214    J094333....
# 21  224    J100040.30+594451.0._12
# 227    J100047....
# 22  235    J100054.87+594436.7._10
# 241    J100100....
# 23  237    J100057.19+594233.8._11
# 239    J100100....
# 24  276    J101614.74+470515.3._13
# 278    J101614....
# 25  277    J101614.76+470523.8._13
# 288    J101621....
# 26  280    J101617.09+470600.8._13
# 317    J101630....
# 27  281    J101617.28+470801.1._14
# 299    J101624....
# 28  295    J101623.83+470732.7._13
# 303    J101625....
# 29  328    J102209.16+013140.6._03
# 333    J102214....
# ..                                                ...
# 31  350    J102221.16+013119.7._02
# 361    J102222....
# 32  360    J102222.46+013051.7._02
# 366    J102224....
# 33  405    J105958.31+251344.3._03
# 410    J110002....
# 34  419    J111231.19+354049.6._19
# 421    J111231....
# 35  450    J113315.65+032647.5._05
# 453    J113321....
# 36  451    J113317.88+032711.9._06
# 456    J113322....
# 37  465    J113329.37+032649.7._06
# 466    J113329....
# 38  476    J113445.85+255520.6._06
# 478    J113448....
# 39  482    J113452.40+255418.0._08
# 491    J113455....
# 40  502    J113459.07+255356.1._05
# 503    J113459....
# 41  534    J123303.11-003138.7._10
# 535    J123303....
# 42  540    J123304.09-003326.0._10
# 543    J123306....
# 43  550    J124146.87+572158.2._10
# 553    J124148....
# 44  577    J141857.73+420711.0._06
# 591    J141902....
# 45  581    J141859.98+420618.5._06
# 594    J141903....
# 46  596    J141904.08+420618.8._05
# 602    J141906....
# 47  587    J141901.21+421010.1._05
# 611    J141908....
# 48  613    J141909.37+420759.4._05
# 618    J141910....
# 49  643    J143704.91+504559.3._08
# 666    J143724....
# 50  645    J143708.95+504621.9._10
# 647    J143713....
# 51  652    J143717.58+504557.9._10
# 654    J143718....
# 52  656    J143719.11+504453.6._09
# 659    J143720....
# 53  658    J143719.71+504450.9._08
# 671    J143726....
# 54  676    J143727.55+504620.9._08
# 678    J143728....
# 55  691    J143733.86+504718.1._08
# 692    J143734....
# 56  709    J155257.05+354920.1._13
# 717    J155259....
# 57  711    J155257.52+354657.4._13
# 739    J155307....
# 58  715    J155259.09+354640.6._13
# 716    J155259....
# 59  727    J155303.55+354726.5._11
# 731    J155304....
# 60  752    J155457.45+362747.6._12
# 755    J155459....
#
#                                            morphology biggestgaltype  \
# 0   0       b'SF'
# 10      b'SF'
# 12    b'SF+E'
# Name...        b'SF+E'
# 1   1     b'SF+E'
# 3       b'SF'
# 18      b'SF'
# Name...        b'SF+E'
# 2   30    b'SF'
# 39    b'SF'
# 49    b'SF'
# Name: gal_...          b'SF'
# 3   40    b'SF+E'
# 44      b'SF'
# 47    b'SF+E'
# Name...        b'SF+E'
# 4   57       b'SF'
# 61       b'SF'
# 75     b'SF+E'
# 8...          b'SF'
# 5   59     b'SF+E'
# 73     b'SF+E'
# 78       b'SF'
# 9...          b'SF'
# 6   69     b'SF'
# 90     b'SF'
# 117    b'SF'
# Name: g...          b'SF'
# 7   74       b'SF'
# 84       b'SF'
# 97     b'SF+E'
# 1...          b'SF'
# 8   79       b'SF'
# 105      b'SF'
# 110      b'SF'
# 1...          b'SF'
# 9   88     b'SF'
# 93     b'SF'
# 116    b'SF'
# Name: g...          b'SF'
# 10  91     b'SF'
# 109    b'SF'
# 119    b'SF'
# 123    ...          b'SF'
# 11  136    b'SF+E'
# 155      b'SF'
# 161      b'SF'
# 1...          b'SF'
# 12  137    b'SF'
# 138    b'SF'
# 141    b'SF'
# 151    ...          b'SF'
# 13  149    b'SF+E'
# 153      b'SF'
# 163      b'SF'
# N...        b'SF+E'
# 14  150    b'SF+E'
# 152      b'SF'
# 154      b'SF'
# N...          b'SF'
# 15  168      b'SF'
# 170    b'SF+E'
# 172      b'SF'
# 1...          b'SF'
# 16  176      b'SF'
# 181    b'SF+E'
# 197      b'SF'
# N...          b'SF'
# 17  186    b'SF'
# 191    b'SF'
# 192    b'SF'
# 195    ...          b'SF'
# 18  187      b'SF'
# 196      b'SF'
# 198    b'SF+E'
# N...          b'SF'
# 19  207    b'SF+E'
# 209    b'SF+E'
# 210    b'SF+E'
# N...        b'SF+E'
# 20  213    b'SF+E'
# 214      b'SF'
# 218    b'SF+E'
# 2...        b'SF+E'
# 21  224      b'SF'
# 227      b'SF'
# 228      b'SF'
# 2...          b'SF'
# 22  235    b'SF+E'
# 241      b'SF'
# 257    b'SF+E'
# 2...        b'SF+E'
# 23  237    b'SF+E'
# 239    b'SF+E'
# 243      b'SF'
# 2...          b'SF'
# 24  276    b'SF+E'
# 278    b'SF+E'
# 282      b'SF'
# 2...          b'SF'
# 25  277      b'SF'
# 288    b'SF+E'
# 293    b'SF+E'
# 3...          b'SF'
# 26  280    b'SF+E'
# 317    b'SF+E'
# 323      b'SF'
# N...        b'SF+E'
# 27  281      b'SF'
# 299      b'SF'
# 307    b'SF+E'
# 3...        b'SF+E'
# 28  295    b'SF+E'
# 303    b'SF+E'
# 324    b'SF+E'
# N...        b'SF+E'
# 29  328    b'SF+E'
# 333    b'SF+E'
# 334      b'SF'
# N...          b'SF'
# ..                                                ...            ...
# 31  350      b'SF'
# 361    b'SF+E'
# 363    b'SF+E'
# 3...        b'SF+E'
# 32  360    b'SF+E'
# 366      b'SF'
# 368      b'SF'
# N...          b'SF'
# 33  405      b'SF'
# 410      b'SF'
# 417    b'SF+E'
# N...          b'SF'
# 34  419    b'SF+E'
# 421    b'SF+E'
# 423    b'SF+E'
# 4...        b'SF+E'
# 35  450    b'SF+E'
# 453    b'SF+E'
# 454    b'SF+E'
# 4...        b'SF+E'
# 36  451    b'SF+E'
# 456      b'SF'
# 467      b'SF'
# N...        b'SF+E'
# 37  465    b'SF+E'
# 466    b'SF+E'
# 470    b'SF+E'
# N...        b'SF+E'
# 38  476    b'SF'
# 478    b'SF'
# 484    b'SF'
# 487    ...          b'SF'
# 39  482    b'SF+E'
# 491      b'SF'
# 499      b'SF'
# N...        b'SF+E'
# 40  502    b'SF+E'
# 503    b'SF+E'
# 508      b'SF'
# 5...        b'SF+E'
# 41  534    b'SF+E'
# 535    b'SF+E'
# 536      b'SF'
# N...        b'SF+E'
# 42  540    b'SF+E'
# 543    b'SF+E'
# 544    b'SF+E'
# 5...        b'SF+E'
# 43  550    b'SF+E'
# 553      b'SF'
# 554    b'SF+E'
# 5...        b'SF+E'
# 44  577    b'SF+E'
# 591      b'SF'
# 593    b'SF+E'
# N...        b'SF+E'
# 45  581      b'SF'
# 594      b'SF'
# 595      b'SF'
# 5...          b'SF'
# 46  596    b'SF+E'
# 602    b'SF+E'
# 621      b'SF'
# N...        b'SF+E'
# 47  587      b'SF'
# 611      b'SF'
# 624    b'SF+E'
# 6...        b'SF+E'
# 48  613    b'SF'
# 618    b'SF'
# 625    b'SF'
# Name: g...          b'SF'
# 49  643      b'SF'
# 666    b'SF+E'
# 703      b'SF'
# N...        b'SF+E'
# 50  645      b'SF'
# 647    b'SF+E'
# 662      b'SF'
# 6...        b'SF+E'
# 51  652    b'SF'
# 654    b'SF'
# 682    b'SF'
# Name: g...          b'SF'
# 52  656    b'SF+E'
# 659    b'SF+E'
# 663    b'SF+E'
# N...        b'SF+E'
# 53  658    b'SF+E'
# 671    b'SF+E'
# 686    b'SF+E'
# 6...        b'SF+E'
# 54  676    b'SF+E'
# 678      b'SF'
# 685      b'SF'
# 6...        b'SF+E'
# 55  691    b'SF+E'
# 692    b'SF+E'
# 693      b'SF'
# N...        b'SF+E'
# 56  709    b'SF+E'
# 717    b'SF+E'
# 724      b'SF'
# 7...        b'SF+E'
# 57  711    b'SF+E'
# 739    b'SF+E'
# 740    b'SF+E'
# N...        b'SF+E'
# 58  715      b'SF'
# 716    b'SF+E'
# 719      b'SF'
# N...          b'SF'
# 59  727      b'SF'
# 731    b'SF+E'
# 737      b'SF'
# 7...          b'SF'
# 60  752    b'SF+E'
# 755    b'SF+E'
# 763    b'SF+E'
# N...        b'SF+E'
#
#                                        stellar_masses  \
# 0   0     8.405740
# 10    8.493776
# 12    9.237293
# N...
# 1   1     10.386827
# 3      8.162347
# 18     8.84550...
# 2   30    8.682405
# 39    8.705125
# 49    9.479523
# N...
# 3   40     9.084104
# 44     9.159035
# 47    11.03056...
# 4   57     10.816021
# 61      8.819493
# 75      8.94...
# 5   59     10.029536
# 73      9.363355
# 78     10.77...
# 6   69     10.393711
# 90      8.713455
# 117     9.35...
# 7   74     10.899514
# 84      9.720776
# 97      9.87...
# 8   79      8.385152
# 105    10.016991
# 110     9.46...
# 9   88     8.406583
# 93     9.080961
# 116    8.65088...
# 10  91     11.315175
# 109    10.907743
# 119     9.87...
# 11  136    9.289264
# 155    9.107329
# 161    9.17260...
# 12  137    10.191614
# 138     9.490131
# 141    11.04...
# 13  149    11.202757
# 153     9.994957
# 163     9.86...
# 14  150     8.158745
# 152    11.682953
# 154     8.63...
# 15  168     8.530757
# 170     9.111173
# 172     8.63...
# 16  176    11.811457
# 181    10.423237
# 197     9.15...
# 17  186     8.613686
# 191     7.932729
# 192     9.42...
# 18  187     9.837980
# 196    10.530492
# 198     9.46...
# 19  207    10.893807
# 209     8.866977
# 210     9.32...
# 20  213     9.707125
# 214     8.694195
# 218    10.01...
# 21  224    10.325436
# 227     9.442047
# 228     8.69...
# 22  235     9.470266
# 241     9.439486
# 257     9.59...
# 23  237     9.155372
# 239     8.476067
# 243    10.09...
# 24  276     9.898322
# 278     7.972036
# 282     9.12...
# 25  277    10.302520
# 288     8.633333
# 293    10.24...
# 26  280    11.161313
# 317    10.824530
# 323     9.92...
# 27  281     9.496166
# 299     9.483203
# 307     9.17...
# 28  295     8.907445
# 303    11.064051
# 324    10.63...
# 29  328     8.463286
# 333     8.426620
# 334    10.71...
# ..                                                ...
# 31  350     8.635663
# 361    11.788202
# 363     8.58...
# 32  360     9.481286
# 366     8.782385
# 368    11.89...
# 33  405    9.403366
# 410    8.820952
# 417    8.81656...
# 34  419    11.092036
# 421     9.262587
# 423     8.88...
# 35  450     9.313680
# 453     9.603414
# 454    10.18...
# 36  451    10.365916
# 456     9.418045
# 467     9.42...
# 37  465    9.214907
# 466    9.734028
# 470    9.68954...
# 38  476    9.477958
# 478    9.722691
# 484    9.57309...
# 39  482    10.482227
# 491     9.215330
# 499     9.65...
# 40  502     9.399581
# 503    11.113384
# 508     9.68...
# 41  534    9.432034
# 535    9.432034
# 536    8.86417...
# 42  540     9.709296
# 543     9.479102
# 544     9.23...
# 43  550    10.081653
# 553     8.502517
# 554    10.16...
# 44  577    11.653812
# 591    10.017536
# 593     9.63...
# 45  581     8.485661
# 594     8.889313
# 595     9.46...
# 46  596     9.317186
# 602    10.559592
# 621     9.02...
# 47  587    9.359834
# 611    9.157968
# 624    8.37251...
# 48  613    10.209694
# 618     8.701060
# 625     9.39...
# 49  643    8.595956
# 666    9.615144
# 703    8.21489...
# 50  645    10.054549
# 647    10.937673
# 662    11.11...
# 51  652    11.283110
# 654     9.650446
# 682     9.39...
# 52  656    10.812742
# 659     9.398558
# 663     8.94...
# 53  658    10.640061
# 671    10.201259
# 686     9.90...
# 54  676    11.109104
# 678     9.574795
# 685    11.44...
# 55  691    10.937677
# 692     9.743704
# 693     9.21...
# 56  709     9.223935
# 717     9.004314
# 724     8.76...
# 57  711    10.170266
# 739    10.644978
# 740     9.06...
# 58  715    8.036078
# 716    8.246564
# 719    9.99781...
# 59  727    7.990991
# 731    8.992486
# 737    9.29521...
# 60  752     9.103222
# 755     9.481825
# 763    11.15...
#
#                                            QSOrho_min  center_QSO_rho
# 0   12    212.200456
# Name: rho_impact, dtype: float64        0.239549
# 1   18    309.147669
# Name: rho_impact, dtype: float64        0.417939
# 2   30    226.299365
# Name: rho_impact, dtype: float64        0.355759
# 3   40    572.241914
# Name: rho_impact, dtype: float64        0.691767
# 4    86    73.018686
# Name: rho_impact, dtype: float64        0.627210
# 5   102    490.254337
# Name: rho_impact, dtype: flo...        0.449945
# 6   90    899.830087
# Name: rho_impact, dtype: float64        0.936858
# 7   101    375.549683
# Name: rho_impact, dtype: flo...        0.254085
# 8   79    142.414824
# Name: rho_impact, dtype: float64        0.326796
# 9   88    231.079987
# Name: rho_impact, dtype: float64        0.272291
# 10  109    502.864166
# Name: rho_impact, dtype: flo...        0.669351
# 11  136    552.453829
# Name: rho_impact, dtype: flo...        0.758807
# 12  141    303.581866
# Name: rho_impact, dtype: flo...        0.340196
# 13  149    315.719541
# Name: rho_impact, dtype: flo...        0.433909
# 14  150    314.999336
# Name: rho_impact, dtype: flo...        0.311530
# 15  177    321.243877
# Name: rho_impact, dtype: flo...        0.379534
# 16  176    360.920261
# Name: rho_impact, dtype: flo...        0.287324
# 17  186    269.394084
# Name: rho_impact, dtype: flo...        0.337755
# 18  187    141.302724
# Name: rho_impact, dtype: flo...        0.366572
# 19  210    102.839092
# Name: rho_impact, dtype: flo...        0.129033
# 20  213    153.896358
# Name: rho_impact, dtype: flo...        0.384278
# 21  250    155.41042
# Name: rho_impact, dtype: float64        0.395772
# 22  235    273.813904
# Name: rho_impact, dtype: flo...        0.328691
# 23   245    36.91707
# Name: rho_impact, dtype: float64        0.235986
# 24  286    80.845804
# Name: rho_impact, dtype: float64        0.143373
# 25  293    447.040794
# Name: rho_impact, dtype: flo...        0.453036
# 26   280    509.8379
# Name: rho_impact, dtype: float64        0.551544
# 27  299    381.322851
# Name: rho_impact, dtype: flo...        0.443457
# 28  303    341.770095
# Name: rho_impact, dtype: flo...        0.391698
# 29  334    467.49673
# Name: rho_impact, dtype: float64        0.470172
# ..                                                ...             ...
# 31  363    363.752931
# Name: rho_impact, dtype: flo...        0.408274
# 32  360    775.332921
# Name: rho_impact, dtype: flo...        1.407118
# 33  410    590.532778
# Name: rho_impact, dtype: flo...        0.612114
# 34  440    254.180955
# Name: rho_impact, dtype: flo...       54.603183
# 35  462    22.528282
# Name: rho_impact, dtype: float64      116.145179
# 36  467    414.320135
# Name: rho_impact, dtype: flo...      181.995406
# 37  465    150.861388
# Name: rho_impact, dtype: flo...      119.762328
# 38  487    258.111675
# Name: rho_impact, dtype: flo...      162.199829
# 39  499    376.80286
# Name: rho_impact, dtype: float64      205.609506
# 40  503    312.277158
# Name: rho_impact, dtype: flo...        0.361316
# 41  534    56.867807
# Name: rho_impact, dtype: float64        0.071977
# 42  544    238.806524
# Name: rho_impact, dtype: flo...        0.405474
# 43  553    273.227683
# Name: rho_impact, dtype: flo...        0.295496
# 44  593    691.657879
# Name: rho_impact, dtype: flo...        0.716621
# 45  612    387.89927
# Name: rho_impact, dtype: float64        0.407706
# 46  621    126.689806
# Name: rho_impact, dtype: flo...        0.207898
# 47  624    76.788837
# Name: rho_impact, dtype: float64        0.250424
# 48  613    122.414144
# Name: rho_impact, dtype: flo...        0.113081
# 49  666    261.495566
# Name: rho_impact, dtype: flo...        0.042494
# 50  667    76.316008
# Name: rho_impact, dtype: float64        0.404090
# 51  682    447.361324
# Name: rho_impact, dtype: flo...        0.493722
# 52  663    201.203053
# Name: rho_impact, dtype: flo...        0.402484
# 53  686    290.791642
# Name: rho_impact, dtype: flo...        0.274464
# 54  676    216.366484
# Name: rho_impact, dtype: flo...        0.568907
# 55  693    556.818694
# Name: rho_impact, dtype: flo...        0.644814
# 56  724    478.405737
# Name: rho_impact, dtype: flo...        0.284146
# 57  739    741.673847
# Name: rho_impact, dtype: flo...        0.757273
# 58  719    478.854259
# Name: rho_impact, dtype: flo...        0.554419
# 59   731    99.42558
# Name: rho_impact, dtype: float64        0.039135
# 60  755    483.318838
# Name: rho_impact, dtype: flo...        0.482911
#
# [61 rows x 18 columns]

# %% [markdown]
# Investigating group 41 real quick because it's messed up

# %%
for ii in range(len(wee_little_groups)):
    big_enough = (10**(wee_little_groups.stellar_masses[ii].nlargest(2).min()))/(10**(wee_little_groups.stellar_masses[ii].nlargest(2).max()))
    if big_enough==1:
        print(ii)
# Out:
# 41

# %%
wee_little_groups.stellar_masses[41].nlargest(2).min(),wee_little_groups.stellar_masses[41].nlargest(2).max()
# Out:
# (9.432034026537147, 9.432034026537147)

# %% [markdown]
# Looks like 534 & 535 aren't the same probably but were given the same stellar mass?

# %% [markdown]
# ### Anyway back to finding the <1/3 ones

# %%
idx_list = []
mass_ratios = []
for ii in range(len(wee_little_groups)):
    big_enough = (10**(wee_little_groups.stellar_masses[ii].nlargest(2).min()))/(10**(wee_little_groups.stellar_masses[ii].nlargest(2).max()))
    if big_enough<0.33:
        idx_list.append(ii)
        mass_ratios.append(big_enough)

# %%
blue_hosts = wee_little_groups.loc[idx_list]
blue_hosts['host_vs_2nd_largest'] = mass_ratios

# %%
len(blue_hosts)
# Out:
# 34

# %% [markdown]
# This is not a particularly large number but whatever

# %%
blue_hosts
# Out:
#     party_size         QSO  redshift_guess  biggest_boi_z  \
# 0            3  J0226+0015        0.352969       0.349424
# 1            3  J0226+0015        0.297729       0.297832
# 2            3  J0809+4619        0.520972       0.520903
# 3            3  J0809+4619        0.532704       0.530117
# 6            3  J0843+4117        0.593428       0.593416
# 7            4  J0843+4117        0.579206       0.580030
# 12           4  J0914+2823        0.600128       0.599377
# 13           3  J0914+2823        0.227620       0.228207
# 14           3  J0914+2823        0.310807       0.311144
# 16           3  J0935+0204        0.353180       0.349514
# 18           3  J0935+0204        0.262358       0.262356
# 19           3  J0943+0531        0.352826       0.349870
# 21           5  J1001+5944        0.374205       0.375555
# 23           6  J1001+5944        0.304297       0.305044
# 27           4  J1016+4706        0.473917       0.476064
# 29           3  J1022+0132        0.306354       0.306360
# 30           3  J1022+0132        0.533907       0.533726
# 31           4  J1022+0132        0.478885       0.478865
# 32           3  J1022+0132        0.778404       0.778528
# 33           3  J1059+2517        0.252350       0.252359
# 36           3  J1133+0327        0.467718       0.467685
# 39           3  J1134+2555        0.682333       0.686190
# 42           4  J1233-0031        0.429621       0.429505
# 44           3  J1419+4207        0.804639       0.804798
# 45          10  J1419+4207        0.523167       0.525289
# 46           3  J1419+4207        0.451054       0.450542
# 48           3  J1419+4207        0.844714       0.845320
# 49           3  J1437+5045        0.129863       0.129806
# 51           3  J1437+5045        0.507022       0.506984
# 52           3  J1437+5045        0.568278       0.568027
# 55           3  J1437+5045        0.662283       0.665170
# 56           5  J1553+3548        0.514815       0.515695
# 58           3  J1553+3548        0.341723       0.341716
# 60           3  J1555+3628        0.473317       0.473284
#
#                      vel_disp                   radius    logmass   center_ra  \
# 0   434.27875527748006 km / s  0.47554728663794493 Mpc  13.541019   36.550684
# 1    82.10966884351586 km / s   0.5454572807064169 Mpc  12.153837   36.534892
# 2   170.96243529961782 km / s   0.4460492822060432 Mpc  12.703472  122.302953
# 3    64.25117503448554 km / s   0.2425109703073517 Mpc  11.588781  122.316879
# 6    587.4728056954765 km / s   0.4896173058758222 Mpc  13.816120  130.961451
# 7     741.130979407261 km / s   0.6160718164183764 Mpc  14.117709  130.958811
# 12   210.4741084339208 km / s   0.4752470294288141 Mpc  12.911604  138.652848
# 13  240.27501987336456 km / s    0.251752369433876 Mpc  12.750678  138.694743
# 14   561.4205251140576 km / s  0.44549509983645014 Mpc  13.735707  138.688157
# 16   822.0843914831577 km / s   0.3401254094698518 Mpc  13.949760  143.823312
# 18  0.9201273020458339 km / s  0.15471800895647564 Mpc   7.705524  143.846282
# 19   655.9707824671318 km / s   0.2454700801315825 Mpc  13.612055  145.877258
# 21  51.016126529871144 km / s   0.5688901390254302 Mpc  11.758731  150.219894
# 23   240.0750518356186 km / s  0.26566115918382893 Mpc  12.773310  150.260730
# 27  455.71223330553465 km / s    0.440068504891036 Mpc  13.549189  154.105707
# 29  49.823274227083125 km / s  0.20176510050950291 Mpc  11.287998  155.560027
# 30   92.17046631377323 km / s   0.4821948323634357 Mpc  12.200694  155.590649
# 31   96.22351642437532 km / s   0.4256346803900126 Mpc  12.183887  155.594120
# 32  211.36513504003636 km / s  0.32625040460533994 Mpc  12.751905  155.604510
# 33  132.99019217487657 km / s  0.18648443087653868 Mpc  12.106569  165.011136
# 36  17.193235872562784 km / s  0.37628639216676374 Mpc  10.634521  165.014694
# 39   37.14685365127767 km / s  0.07194602335718978 Mpc  10.585139  165.014694
# 42   61.12559304011862 km / s  0.30678702056675555 Mpc  11.647571  188.276403
# 44   78.79438613759665 km / s    0.500663331857725 Mpc  12.080824  214.760092
# 45   448.4756817567214 km / s   0.8004768097057685 Mpc  13.795114  214.774654
# 46   547.3745465285758 km / s   0.5152001720735138 Mpc  13.776833  214.780044
# 48   663.2489729066789 km / s    0.467671855190145 Mpc  13.901582  214.792490
# 49  30.811119942886368 km / s   0.4409059561591224 Mpc  11.210049  219.351719
# 51  20.137643239144477 km / s  0.44537453376787595 Mpc  10.845030  219.324709
# 52  453.73883226033576 km / s  0.20575947679303447 Mpc  13.215259  219.334858
# 55                 0.0 km / s  0.29146352500080314 Mpc       -inf  219.392225
# 56   244.6061982685603 km / s   0.5849852395413537 Mpc  13.132367  238.258513
# 58  3.3539954627102717 km / s  0.08672124371833087 Mpc   8.577538  238.247110
# 60   16.61013805659391 km / s  0.38276978095884173 Mpc  10.611972  238.749078
#
#     center_dec  biggest_boi_gal_ra  biggest_boi_gal_dec  \
# 0     0.249508           36.550751             0.251680
# 1     0.259185           36.510059             0.260170
# 2    46.331768          122.327316            46.334530
# 3    46.342665          122.326057            46.326328
# 6    41.332694          130.936050            41.334000
# 7    41.305138          130.938828            41.329262
# 12   28.389869          138.656982            28.384680
# 13   28.413870          138.675736            28.414169
# 14   28.386134          138.689453            28.385309
# 16    2.086358          143.810104             2.082890
# 18    2.084222          143.846161             2.084710
# 19    5.530814          145.862518             5.543740
# 21   59.734655          150.167892            59.747490
# 23   59.723170          150.258621            59.717300
# 27   47.130616          154.127747            47.146400
# 29    1.518050          155.560059             1.518240
# 30    1.555789          155.590790             1.557300
# 31    1.527781          155.593658             1.494020
# 32    1.494220          155.606110             1.495270
# 33   25.246529          164.992950            25.228970
# 36    3.455419          165.014694             3.453310
# 39   25.905016          165.014694            25.904989
# 42   -0.543167          188.295471            -0.552460
# 44   42.120558          214.740555            42.119709
# 45   42.141278          214.781998            42.169891
# 46   42.126707          214.778671            42.152611
# 48   42.133696          214.789032            42.133171
# 49   50.763601          219.354141            50.735260
# 51   50.764800          219.323227            50.766079
# 52   50.758727          219.329620            50.748230
# 55   50.778816          219.391067            50.788361
# 56   35.815565          238.263519            35.784729
# 58   35.783810          238.250778            35.786800
# 60   36.464416          238.778564            36.448349
#
#               center_diff_mpc  \
# 0    0.040052623315028735 Mpc
# 1     0.40884518542015885 Mpc
# 2      0.3942891142330133 Mpc
# 3      0.4099305197415455 Mpc
# 6       0.471335122535602 Mpc
# 7      0.6925436901812984 Mpc
# 12    0.15706069860002936 Mpc
# 13    0.22641968877730564 Mpc
# 14   0.023841491589075694 Mpc
# 16     0.2516893774364515 Mpc
# 18  0.0075589319581334385 Mpc
# 19     0.3603675203576696 Mpc
# 21     0.5582834513509644 Mpc
# 23     0.0996189150353009 Mpc
# 27     0.4787481383519877 Mpc
# 29  0.0032222435335531848 Mpc
# 30    0.03555141296424195 Mpc
# 31      0.746806925710699 Mpc
# 32   0.052689307329322935 Mpc
# 33    0.35182302846648783 Mpc
# 36    0.04603875510666545 Mpc
# 39  0.0006937468181190323 Mpc
# 42      0.441247052631416 Mpc
# 44    0.40440868833504784 Mpc
# 45     0.6751293903305702 Mpc
# 46     0.5545832071215141 Mpc
# 48    0.07408164431484704 Mpc
# 49    0.24422837856685295 Mpc
# 51    0.03616082384349955 Mpc
# 52     0.2658798967610465 Mpc
# 55    0.24776421649996064 Mpc
# 56     0.7149615176251402 Mpc
# 58    0.07615675168814216 Mpc
# 60       0.62954707824123 Mpc
#
#                                            member_ids  \
# 0   0     J022601.51+001532.5._03
# 10    J022612.15...
# 1   1     J022602.41+001536.6._01
# 3     J022607.08...
# 2   30    J080905.28+461944.8._01
# 39    J080913.54...
# 3   40    J080913.68+462032.5._04
# 44    J080916.16...
# 6   69     J084344.65+412002.4._05
# 90     J084350....
# 7   74     J084345.32+411945.3._04
# 84     J084348....
# 12  137    J091436.16+282334.9._02
# 138    J091436....
# 13  149    J091442.18+282451.0._02
# 153    J091446....
# 14  150    J091442.85+282231.7._01
# 152    J091445....
# 16  176    J093514.43+020458.4._08
# 181    J093516....
# 18  187    J093519.30+020445.0._09
# 196    J093523....
# 19  207    J094327.00+053237.5._02
# 209    J094330....
# 21  224    J100040.30+594451.0._12
# 227    J100047....
# 23  237    J100057.19+594233.8._11
# 239    J100100....
# 27  281    J101617.28+470801.1._14
# 299    J101624....
# 29  328    J102209.16+013140.6._03
# 333    J102214....
# 30  340    J102215.98+013126.4._03
# 352    J102221....
# 31  350    J102221.16+013119.7._02
# 361    J102222....
# 32  360    J102222.46+013051.7._02
# 366    J102224....
# 33  405    J105958.31+251344.3._03
# 410    J110002....
# 36  451    J113317.88+032711.9._06
# 456    J113322....
# 39  482    J113452.40+255418.0._08
# 491    J113455....
# 42  540    J123304.09-003326.0._10
# 543    J123306....
# 44  577    J141857.73+420711.0._06
# 591    J141902....
# 45  581    J141859.98+420618.5._06
# 594    J141903....
# 46  596    J141904.08+420618.8._05
# 602    J141906....
# 48  613    J141909.37+420759.4._05
# 618    J141910....
# 49  643    J143704.91+504559.3._08
# 666    J143724....
# 51  652    J143717.58+504557.9._10
# 654    J143718....
# 52  656    J143719.11+504453.6._09
# 659    J143720....
# 55  691    J143733.86+504718.1._08
# 692    J143734....
# 56  709    J155257.05+354920.1._13
# 717    J155259....
# 58  715    J155259.09+354640.6._13
# 716    J155259....
# 60  752    J155457.45+362747.6._12
# 755    J155459....
#
#                                            morphology biggestgaltype  \
# 0   0       b'SF'
# 10      b'SF'
# 12    b'SF+E'
# Name...        b'SF+E'
# 1   1     b'SF+E'
# 3       b'SF'
# 18      b'SF'
# Name...        b'SF+E'
# 2   30    b'SF'
# 39    b'SF'
# 49    b'SF'
# Name: gal_...          b'SF'
# 3   40    b'SF+E'
# 44      b'SF'
# 47    b'SF+E'
# Name...        b'SF+E'
# 6   69     b'SF'
# 90     b'SF'
# 117    b'SF'
# Name: g...          b'SF'
# 7   74       b'SF'
# 84       b'SF'
# 97     b'SF+E'
# 1...          b'SF'
# 12  137    b'SF'
# 138    b'SF'
# 141    b'SF'
# 151    ...          b'SF'
# 13  149    b'SF+E'
# 153      b'SF'
# 163      b'SF'
# N...        b'SF+E'
# 14  150    b'SF+E'
# 152      b'SF'
# 154      b'SF'
# N...          b'SF'
# 16  176      b'SF'
# 181    b'SF+E'
# 197      b'SF'
# N...          b'SF'
# 18  187      b'SF'
# 196      b'SF'
# 198    b'SF+E'
# N...          b'SF'
# 19  207    b'SF+E'
# 209    b'SF+E'
# 210    b'SF+E'
# N...        b'SF+E'
# 21  224      b'SF'
# 227      b'SF'
# 228      b'SF'
# 2...          b'SF'
# 23  237    b'SF+E'
# 239    b'SF+E'
# 243      b'SF'
# 2...          b'SF'
# 27  281      b'SF'
# 299      b'SF'
# 307    b'SF+E'
# 3...        b'SF+E'
# 29  328    b'SF+E'
# 333    b'SF+E'
# 334      b'SF'
# N...          b'SF'
# 30  340    b'SF+E'
# 352      b'SF'
# 353    b'SF+E'
# N...        b'SF+E'
# 31  350      b'SF'
# 361    b'SF+E'
# 363    b'SF+E'
# 3...        b'SF+E'
# 32  360    b'SF+E'
# 366      b'SF'
# 368      b'SF'
# N...          b'SF'
# 33  405      b'SF'
# 410      b'SF'
# 417    b'SF+E'
# N...          b'SF'
# 36  451    b'SF+E'
# 456      b'SF'
# 467      b'SF'
# N...        b'SF+E'
# 39  482    b'SF+E'
# 491      b'SF'
# 499      b'SF'
# N...        b'SF+E'
# 42  540    b'SF+E'
# 543    b'SF+E'
# 544    b'SF+E'
# 5...        b'SF+E'
# 44  577    b'SF+E'
# 591      b'SF'
# 593    b'SF+E'
# N...        b'SF+E'
# 45  581      b'SF'
# 594      b'SF'
# 595      b'SF'
# 5...          b'SF'
# 46  596    b'SF+E'
# 602    b'SF+E'
# 621      b'SF'
# N...        b'SF+E'
# 48  613    b'SF'
# 618    b'SF'
# 625    b'SF'
# Name: g...          b'SF'
# 49  643      b'SF'
# 666    b'SF+E'
# 703      b'SF'
# N...        b'SF+E'
# 51  652    b'SF'
# 654    b'SF'
# 682    b'SF'
# Name: g...          b'SF'
# 52  656    b'SF+E'
# 659    b'SF+E'
# 663    b'SF+E'
# N...        b'SF+E'
# 55  691    b'SF+E'
# 692    b'SF+E'
# 693      b'SF'
# N...        b'SF+E'
# 56  709    b'SF+E'
# 717    b'SF+E'
# 724      b'SF'
# 7...        b'SF+E'
# 58  715      b'SF'
# 716    b'SF+E'
# 719      b'SF'
# N...          b'SF'
# 60  752    b'SF+E'
# 755    b'SF+E'
# 763    b'SF+E'
# N...        b'SF+E'
#
#                                        stellar_masses  \
# 0   0     8.405740
# 10    8.493776
# 12    9.237293
# N...
# 1   1     10.386827
# 3      8.162347
# 18     8.84550...
# 2   30    8.682405
# 39    8.705125
# 49    9.479523
# N...
# 3   40     9.084104
# 44     9.159035
# 47    11.03056...
# 6   69     10.393711
# 90      8.713455
# 117     9.35...
# 7   74     10.899514
# 84      9.720776
# 97      9.87...
# 12  137    10.191614
# 138     9.490131
# 141    11.04...
# 13  149    11.202757
# 153     9.994957
# 163     9.86...
# 14  150     8.158745
# 152    11.682953
# 154     8.63...
# 16  176    11.811457
# 181    10.423237
# 197     9.15...
# 18  187     9.837980
# 196    10.530492
# 198     9.46...
# 19  207    10.893807
# 209     8.866977
# 210     9.32...
# 21  224    10.325436
# 227     9.442047
# 228     8.69...
# 23  237     9.155372
# 239     8.476067
# 243    10.09...
# 27  281     9.496166
# 299     9.483203
# 307     9.17...
# 29  328     8.463286
# 333     8.426620
# 334    10.71...
# 30  340     9.478680
# 352     8.594994
# 353    11.55...
# 31  350     8.635663
# 361    11.788202
# 363     8.58...
# 32  360     9.481286
# 366     8.782385
# 368    11.89...
# 33  405    9.403366
# 410    8.820952
# 417    8.81656...
# 36  451    10.365916
# 456     9.418045
# 467     9.42...
# 39  482    10.482227
# 491     9.215330
# 499     9.65...
# 42  540     9.709296
# 543     9.479102
# 544     9.23...
# 44  577    11.653812
# 591    10.017536
# 593     9.63...
# 45  581     8.485661
# 594     8.889313
# 595     9.46...
# 46  596     9.317186
# 602    10.559592
# 621     9.02...
# 48  613    10.209694
# 618     8.701060
# 625     9.39...
# 49  643    8.595956
# 666    9.615144
# 703    8.21489...
# 51  652    11.283110
# 654     9.650446
# 682     9.39...
# 52  656    10.812742
# 659     9.398558
# 663     8.94...
# 55  691    10.937677
# 692     9.743704
# 693     9.21...
# 56  709     9.223935
# 717     9.004314
# 724     8.76...
# 58  715    8.036078
# 716    8.246564
# 719    9.99781...
# 60  752     9.103222
# 755     9.481825
# 763    11.15...
#
#                                            QSOrho_min  center_QSO_rho  \
# 0   12    212.200456
# Name: rho_impact, dtype: float64        0.239549
# 1   18    309.147669
# Name: rho_impact, dtype: float64        0.417939
# 2   30    226.299365
# Name: rho_impact, dtype: float64        0.355759
# 3   40    572.241914
# Name: rho_impact, dtype: float64        0.691767
# 6   90    899.830087
# Name: rho_impact, dtype: float64        0.936858
# 7   101    375.549683
# Name: rho_impact, dtype: flo...        0.254085
# 12  141    303.581866
# Name: rho_impact, dtype: flo...        0.340196
# 13  149    315.719541
# Name: rho_impact, dtype: flo...        0.433909
# 14  150    314.999336
# Name: rho_impact, dtype: flo...        0.311530
# 16  176    360.920261
# Name: rho_impact, dtype: flo...        0.287324
# 18  187    141.302724
# Name: rho_impact, dtype: flo...        0.366572
# 19  210    102.839092
# Name: rho_impact, dtype: flo...        0.129033
# 21  250    155.41042
# Name: rho_impact, dtype: float64        0.395772
# 23   245    36.91707
# Name: rho_impact, dtype: float64        0.235986
# 27  299    381.322851
# Name: rho_impact, dtype: flo...        0.443457
# 29  334    467.49673
# Name: rho_impact, dtype: float64        0.470172
# 30  340    452.192237
# Name: rho_impact, dtype: flo...        0.485326
# 31  363    363.752931
# Name: rho_impact, dtype: flo...        0.408274
# 32  360    775.332921
# Name: rho_impact, dtype: flo...        1.407118
# 33  410    590.532778
# Name: rho_impact, dtype: flo...        0.612114
# 36  467    414.320135
# Name: rho_impact, dtype: flo...      181.995406
# 39  499    376.80286
# Name: rho_impact, dtype: float64      205.609506
# 42  544    238.806524
# Name: rho_impact, dtype: flo...        0.405474
# 44  593    691.657879
# Name: rho_impact, dtype: flo...        0.716621
# 45  612    387.89927
# Name: rho_impact, dtype: float64        0.407706
# 46  621    126.689806
# Name: rho_impact, dtype: flo...        0.207898
# 48  613    122.414144
# Name: rho_impact, dtype: flo...        0.113081
# 49  666    261.495566
# Name: rho_impact, dtype: flo...        0.042494
# 51  682    447.361324
# Name: rho_impact, dtype: flo...        0.493722
# 52  663    201.203053
# Name: rho_impact, dtype: flo...        0.402484
# 55  693    556.818694
# Name: rho_impact, dtype: flo...        0.644814
# 56  724    478.405737
# Name: rho_impact, dtype: flo...        0.284146
# 58  719    478.854259
# Name: rho_impact, dtype: flo...        0.554419
# 60  755    483.318838
# Name: rho_impact, dtype: flo...        0.482911
#
#     host_vs_2nd_largest
# 0              0.180502
# 1              0.028752
# 2              0.168113
# 3              0.013442
# 6              0.091290
# 7              0.142579
# 12             0.138638
# 13             0.061973
# 14             0.000895
# 16             0.040905
# 18             0.202996
# 19             0.026936
# 21             0.130801
# 23             0.249290
# 27             0.045630
# 29             0.005660
# 30             0.008382
# 31             0.004996
# 32             0.003827
# 33             0.261568
# 36             0.113903
# 39             0.147314
# 42             0.322758
# 44             0.023106
# 45             0.143845
# 46             0.057226
# 48             0.153806
# 49             0.095678
# 51             0.023299
# 52             0.038532
# 55             0.063977
# 56             0.104965
# 58             0.017731
# 60             0.021202

# %%
biggalaxy=gal_info[gal_info['id']==blue_hosts.member_ids[0].loc[12]]
galaxy2=gal_info[gal_info['id']==blue_hosts.member_ids[0].loc[10]]
galaxy3=gal_info[gal_info['id']==blue_hosts.member_ids[0].loc[0]]

# %%
big_loc = SkyCoord(biggalaxy.gal_ra*u.deg, biggalaxy.gal_dec*u.deg)
gal2loc = SkyCoord(galaxy2.gal_ra*u.deg, galaxy2.gal_dec*u.deg)
gal3loc = SkyCoord(galaxy3.gal_ra*u.deg, galaxy3.gal_dec*u.deg)

# %% [markdown]
# Let's plot those and see what's up

# %%
centercoords = SkyCoord(blue_hosts.center_ra.loc[0]*u.deg,blue_hosts.center_dec.loc[0]*u.deg)

# %%
QSOordinates = SkyCoord(gal_info.RA_QSO.loc[0]*u.deg,gal_info.DEC_QSO.loc[0]*u.deg)

# %%
plt.scatter(QSOordinates.ra,QSOordinates.dec,c='g',s=250,label='QSO')
plt.scatter(centercoords.ra,centercoords.dec,c='y',s=200,label='Center from Vel Dispersion')
plt.scatter([big_loc.ra,gal2loc.ra,gal3loc.ra],[big_loc.dec,gal2loc.dec,gal3loc.dec],s=[100,50,40])
plt.legend()
plt.xlabel('ra (deg)')
plt.ylabel('dec (deg)')
plt.title('Isolated host in {0:s} at z={1:.4f}'.format(gal_info.OBJECT.loc[0],blue_hosts.redshift_guess.loc[0]));

# %% [markdown]
# Doing another one manually:

# %%
blue_hosts.member_ids.loc[42],blue_hosts.stellar_masses[42].nlargest(1)
# Out:
# (540    J123304.09-003326.0._10
#  543    J123306.33-003201.1._09
#  544    J123306.48-003146.1._10
#  548    J123310.91-003308.9._09
#  Name: id, dtype: object, 548    10.200419
#  Name: mstars, dtype: float64)

# %%
bigg42=gal_info[gal_info['id']==blue_hosts.member_ids[42].loc[548]]
g42_2=gal_info[gal_info['id']==blue_hosts.member_ids[42].loc[540]]
g42_3=gal_info[gal_info['id']==blue_hosts.member_ids[42].loc[543]]
g42_4=gal_info[gal_info['id']==blue_hosts.member_ids[42].loc[544]]

# %%
big42_loc = SkyCoord(bigg42.gal_ra*u.deg, bigg42.gal_dec*u.deg)
g42_2loc = SkyCoord(g42_2.gal_ra*u.deg, g42_2.gal_dec*u.deg)
g42_3loc = SkyCoord(g42_3.gal_ra*u.deg, g42_3.gal_dec*u.deg)
g42_4loc = SkyCoord(g42_4.gal_ra*u.deg, g42_4.gal_dec*u.deg)

# %%
posangles2=big42_loc.position_angle(g42_2loc).degree
posangles3=big42_loc.position_angle(g42_3loc).degree
posangles4=big42_loc.position_angle(g42_4loc).degree

# %%
centercoords42 = SkyCoord(blue_hosts.center_ra.loc[42]*u.deg,blue_hosts.center_dec.loc[42]*u.deg)
QSOordinates42 = SkyCoord(gal_info.RA_QSO.loc[548]*u.deg,gal_info.DEC_QSO.loc[548]*u.deg)

# %%
plt.scatter(QSOordinates42.ra,QSOordinates42.dec,c='g',s=250,label='QSO')
plt.scatter(centercoords42.ra,centercoords42.dec,c='y',s=200,label='Center from Vel Dispersion')
plt.scatter([big42_loc.ra,g42_2loc.ra,g42_3loc.ra,g42_4loc.ra],[big42_loc.dec,g42_2loc.dec,g42_3loc.dec,g42_4loc.dec],s=[100,50,50,50],label='Group Members')
plt.legend()
plt.ylim(-0.56,-0.50)
plt.xlabel('ra (deg)')
plt.ylabel('dec (deg)')
plt.title('Isolated host in {0:s} at z={1:.4f}'.format(gal_info.OBJECT.loc[548],blue_hosts.redshift_guess.loc[42]));

# %% [markdown]
# Defining same and opposite sides according to $\Delta \phi$, as illustrated in figure 3 of Brainerd & Samuels 2020.

# %%
# this is to say that there don't appear to be any red hosts
# (but actually some of those SF+Es could be though)

blue_hosts.biggestgaltype.unique()
# Out:
# array(["b'SF+E'", "b'SF'"], dtype=object)

# %% [markdown]
# ### Gathering $\Delta$ position angles:

# %%
list_o_lists2 = []
dist_list = []
largest_dist_list = []
distmin = []
for ii in range(blue_hosts.index.max()+1):
    try:
        that_big_boiii = blue_hosts.stellar_masses.loc[ii].max()
        # WAIT WAIT this last fix messed some other ones up:
        #largestgalaxy = gal_info[(gal_info['mstars']==that_big_boiii)&(gal_info.specfile.isna()==False)]
        largestgalaxy = gal_info[gal_info['mstars']==that_big_boiii]
        smallbois = blue_hosts.stellar_masses.loc[ii].nsmallest(len(blue_hosts.stellar_masses.loc[ii])-1)
        
        # this is horrible and ugly, but it's the first way of doing this that I could get to work:
        stars = []
        for index,mass in enumerate(smallbois):
            stars.append(mass)
        small_bois = gal_info.loc[np.where(gal_info.mstars.isin(stars))]
        
        big_boi_loc = SkyCoord(largestgalaxy.gal_ra*u.deg, largestgalaxy.gal_dec*u.deg)
        small_bois_loc = SkyCoord(small_bois.gal_ra*u.deg, small_bois.gal_dec*u.deg)
        # distance:
        dist_rad = big_boi_loc.separation(small_bois_loc)
        dists_to_largest = dist_rad.radian*cosm.angular_diameter_distance(blue_hosts.redshift_guess.loc[ii]).value
        dist_list.append(dists_to_largest)
        largest_dist_list.append(np.max(dists_to_largest))
        distmin.append(np.min(dists_to_largest))
        # next calculate position angle betwixt big and small bois
        posanglelist = []
        for galaxy in small_bois_loc:
            posangle = big_boi_loc.position_angle(galaxy).degree
            posanglelist.append(posangle)
        deltaposanglelist = []
        try:
            for jj in range(len(posanglelist)):
                delta_posangle = posanglelist-posanglelist[jj]
                deltaposanglelist.append(delta_posangle)
        except ValueError:
            deltaposanglelist.append(np.nan)
        if deltaposanglelist == []:
            deltaposanglelist.append(np.nan)
        deltaposanglelist = np.array(deltaposanglelist)
        deltaposanglelist = deltaposanglelist[np.where((deltaposanglelist>0))]
        deltaposanglelist = np.where(deltaposanglelist>180,360-deltaposanglelist,deltaposanglelist)
        list_o_lists2.append(deltaposanglelist)
    except KeyError:
        continue

# %%
blue_hosts.loc[39] # all have exactly the same RA?
# Out:
# party_size                                                             3
# QSO                                                           J1134+2555
# redshift_guess                                                  0.682333
# biggest_boi_z                                                    0.68619
# vel_disp                                        37.14685365127767 km / s
# radius                                           0.07194602335718978 Mpc
# logmass                                                          10.5851
# center_ra                                                        165.015
# center_dec                                                        25.905
# biggest_boi_gal_ra                                               165.015
# biggest_boi_gal_dec                                               25.905
# center_diff_mpc                                0.0006937468181190323 Mpc
# member_ids             482    J113452.40+255418.0._08
# 491    J113455....
# morphology             482    b'SF+E'
# 491      b'SF'
# 499      b'SF'
# N...
# biggestgaltype                                                   b'SF+E'
# stellar_masses         482    10.482227
# 491     9.215330
# 499     9.65...
# QSOrho_min             499    376.80286
# Name: rho_impact, dtype: float64
# center_QSO_rho                                                    205.61
# host_vs_2nd_largest                                             0.147314
# Name: 39, dtype: object

# %%
blue_hosts['delta_pos_angles'] = list_o_lists2

# %%
blue_hosts['distances_to_largest'] = dist_list
blue_hosts['max_dist_to_largest'] = largest_dist_list
blue_hosts['min_dist'] = distmin
# group names
blue_hosts['group_name']=(blue_hosts.QSO+'_'+(blue_hosts.redshift_guess.round(4)).astype('str'))

# %% [markdown]
# For binning: [0,60] = same side, [60,120] = could go either way, [120,180] = opposite sides, remember SORT-OF-modulo 180

# %%
bins = [0.0001,30,60,90,120,150,180]

# %%
plt.hist(blue_hosts.query('party_size<11').delta_pos_angles,bins=bins,stacked=True, density=True)
plt.xlabel('$\Delta \phi$ (Degrees)')
plt.ylabel('Density')
plt.title('Distribution of Satellite Galaxies around Isolated Blue Hosts');

# %%
# now how about:

bins2 = [0.001,90,180]

plt.hist(blue_hosts.query('party_size<11').delta_pos_angles,bins=bins2,stacked=True,density=True)
plt.xlabel('$\Delta \phi$ (Degrees)')
plt.ylabel('Density')
plt.title('Distribution of Satellite Galaxies around Isolated Blue Hosts');

# %% [markdown]
# k...

# %%
# plotting the big one (i.e. the group of 10) just for fun

# %%
smallbois = blue_hosts.stellar_masses.loc[45].nsmallest(len(blue_hosts.stellar_masses.loc[45])-1)
stars = []
for index,mass in enumerate(smallbois):
    stars.append(mass)
small_bois = gal_info.loc[np.where(gal_info.mstars.isin(stars))]
small_bois_loc = SkyCoord(small_bois.gal_ra*u.deg, small_bois.gal_dec*u.deg)
QSOordinates45 = SkyCoord(gal_info.RA_QSO.loc[581]*u.deg,gal_info.DEC_QSO.loc[581]*u.deg)

# %%
plt.scatter(QSOordinates45.ra,QSOordinates45.dec,c='g',s=250,label='QSO')
plt.scatter(blue_hosts.center_ra.loc[45],blue_hosts.center_dec.loc[45],c='y',s=200,label='Center from Vel Dispersion')
plt.scatter([blue_hosts.biggest_boi_gal_ra.loc[45]],[blue_hosts.biggest_boi_gal_dec.loc[45]],c='b',s=100,label='Biggest Group Member')
plt.scatter(small_bois_loc.ra,small_bois_loc.dec,c='xkcd:Barbie Pink',label='Group Members')
plt.legend(loc=6,fontsize=8)
plt.gca().set_facecolor('xkcd:night blue')
plt.xlim(214.74,214.8)
plt.xlabel('ra (deg)')
plt.ylabel('dec (deg)')
plt.title('Isolated host in {0:s} at z={1:.4f}'.format(blue_hosts.QSO.loc[45],blue_hosts.redshift_guess.loc[45]));

# %%
# impact param of host
print(gal_info.rho_impact.loc[607])
# min impact param
print(blue_hosts.QSOrho_min.loc[45])
# Out:
# 950.9344649172664
# 612    387.89927
# Name: rho_impact, dtype: float64

# %% [markdown]
# And there is some absorption there.

# %% [markdown]
# #### Plotting the highest redshift because why not:

# %%
blue_hosts.nlargest(2,columns='redshift_guess')
# Out:
#     party_size         QSO  redshift_guess  biggest_boi_z  \
# 48           3  J1419+4207        0.844714       0.845320
# 44           3  J1419+4207        0.804639       0.804798
#
#                     vel_disp                 radius    logmass   center_ra  \
# 48  663.2489729066789 km / s  0.467671855190145 Mpc  13.901582  214.792490
# 44  78.79438613759665 km / s  0.500663331857725 Mpc  12.080824  214.760092
#
#     center_dec  biggest_boi_gal_ra  ...  biggestgaltype  \
# 48   42.133696          214.789032  ...           b'SF'
# 44   42.120558          214.740555  ...         b'SF+E'
#
#                                        stellar_masses  \
# 48  613    10.209694
# 618     8.701060
# 625     9.39...
# 44  577    11.653812
# 591    10.017536
# 593     9.63...
#
#                                            QSOrho_min center_QSO_rho  \
# 48  613    122.414144
# Name: rho_impact, dtype: flo...       0.113081
# 44  593    691.657879
# Name: rho_impact, dtype: flo...       0.716621
#
#    host_vs_2nd_largest      delta_pos_angles  \
# 48            0.153806  [105.90687606352859]
# 44            0.023106  [101.97514682702563]
#
#                          distances_to_largest  max_dist_to_largest  min_dist  \
# 48  [0.06382947751925189, 0.9158331774191497]             0.915833  0.063829
# 44   [0.5918906202936364, 0.6941374452470978]             0.694137  0.591891
#
#            group_name
# 48  J1419+4207_0.8447
# 44  J1419+4207_0.8046
#
# [2 rows x 24 columns]

# %% [markdown]
# okay so here's 48, at $z=0.845$-ish in `J1419+4207`:

# %%
smallbois = blue_hosts.stellar_masses.loc[48].nsmallest(len(blue_hosts.stellar_masses.loc[48])-1)
stars = [] # note: stars as in stellar mass
for index,mass in enumerate(smallbois):
    stars.append(mass)
small_bois = gal_info.loc[np.where(gal_info.mstars.isin(stars))]
small_bois_loc = SkyCoord(small_bois.gal_ra*u.deg, small_bois.gal_dec*u.deg)
QSOordinates48 = SkyCoord(gal_info.RA_QSO.loc[625]*u.deg,gal_info.DEC_QSO.loc[625]*u.deg)

# %%
plt.scatter(QSOordinates48.ra,QSOordinates48.dec,c='g',s=250,label='QSO')
plt.scatter(blue_hosts.center_ra.loc[48],blue_hosts.center_dec.loc[48],c='y',s=200,label='Center from Vel Dispersion')
plt.scatter([blue_hosts.biggest_boi_gal_ra.loc[48]],[blue_hosts.biggest_boi_gal_dec.loc[48]],c='b',s=100,label='Biggest Group Member')
plt.scatter(small_bois_loc.ra,small_bois_loc.dec,c='xkcd:Barbie Pink',label='Group Members')
plt.legend(fontsize=8)
#plt.xlim(214.74,214.8)
plt.xlabel('ra (deg)')
plt.ylabel('dec (deg)')
plt.title('Isolated host in {0:s} at z={1:.4f}'.format(blue_hosts.QSO.loc[48],blue_hosts.redshift_guess.loc[48]));

# %%
smallbois = blue_hosts.stellar_masses.loc[44].nsmallest(len(blue_hosts.stellar_masses.loc[44])-1)
stars = [] # note: stars as in stellar mass
for index,mass in enumerate(smallbois):
    stars.append(mass)
small_bois = gal_info.loc[np.where(gal_info.mstars.isin(stars))]
small_bois_loc = SkyCoord(small_bois.gal_ra*u.deg, small_bois.gal_dec*u.deg)
QSOordinates44 = SkyCoord(gal_info.RA_QSO.loc[591]*u.deg,gal_info.DEC_QSO.loc[591]*u.deg)

# %%
plt.scatter(QSOordinates44.ra,QSOordinates44.dec,c='g',s=250,label='QSO')
plt.scatter(blue_hosts.center_ra.loc[44],blue_hosts.center_dec.loc[44],c='y',s=200,label='Center from Vel Dispersion')
plt.scatter([blue_hosts.biggest_boi_gal_ra.loc[44]],[blue_hosts.biggest_boi_gal_dec.loc[44]],c='b',s=100,label='Biggest Group Member')
plt.scatter(small_bois_loc.ra,small_bois_loc.dec,c='xkcd:Barbie Pink',label='Group Members')
plt.legend(fontsize=8)
#plt.xlim(214.74,214.8)
plt.xlabel('ra (deg)')
plt.ylabel('dec (deg)')
plt.title('Isolated host in {0:s} at z={1:.4f}'.format(blue_hosts.QSO.loc[44],blue_hosts.redshift_guess.loc[44]));

# %% [markdown]
# ### Plotting a couple where minpact par is small but there is no absorption:

# %%
blue_hosts.query("group_name=='J0935+0204_0.2624'")
# Out:
#     party_size         QSO  redshift_guess  biggest_boi_z  \
# 18           3  J0935+0204        0.262358       0.262356
#
#                      vel_disp                   radius   logmass   center_ra  \
# 18  0.9201273020458339 km / s  0.15471800895647564 Mpc  7.705524  143.846282
#
#     center_dec  biggest_boi_gal_ra  ...  biggestgaltype  \
# 18    2.084222          143.846161  ...           b'SF'
#
#                                        stellar_masses  \
# 18  187     9.837980
# 196    10.530492
# 198     9.46...
#
#                                            QSOrho_min center_QSO_rho  \
# 18  187    141.302724
# Name: rho_impact, dtype: flo...       0.366572
#
#    host_vs_2nd_largest     delta_pos_angles  \
# 18            0.202996  [173.1349631084515]
#
#                           distances_to_largest  max_dist_to_largest  min_dist  \
# 18  [0.2509522439927861, 0.058825625670392345]             0.250952  0.058826
#
#            group_name
# 18  J0935+0204_0.2624
#
# [1 rows x 24 columns]

# %%
smallbois = blue_hosts.stellar_masses.loc[18].nsmallest(len(blue_hosts.stellar_masses.loc[18])-1)
stars = [] # note: stars as in stellar mass
for index,mass in enumerate(smallbois):
    stars.append(mass)
small_bois = gal_info.loc[np.where(gal_info.mstars.isin(stars))]
small_bois_loc = SkyCoord(small_bois.gal_ra*u.deg, small_bois.gal_dec*u.deg)
QSOordinates18 = SkyCoord(gal_info.RA_QSO.loc[187]*u.deg,gal_info.DEC_QSO.loc[187]*u.deg)

# %%
plt.scatter(blue_hosts.center_ra.loc[18],blue_hosts.center_dec.loc[18],c='y',s=200,label='Center from Vel Dispersion')
plt.scatter([blue_hosts.biggest_boi_gal_ra.loc[18]],[blue_hosts.biggest_boi_gal_dec.loc[18]],c='b',s=100,label='Biggest Group Member')
plt.scatter(small_bois_loc.ra,small_bois_loc.dec,c='xkcd:Barbie Pink',label='Group Members')
plt.scatter(QSOordinates18.ra,QSOordinates18.dec,c='g',s=250,label='QSO')
plt.legend(fontsize=8)
plt.xlabel('ra (deg)')
plt.ylabel('dec (deg)')
plt.title('Isolated host in {0:s} at z={1:.4f}'.format(blue_hosts.QSO.loc[18],blue_hosts.redshift_guess.loc[18]));

# %% [markdown]
# And another:

# %%
blue_hosts.query("group_name=='J1001+5944_0.3742'")
# Out:
#     party_size         QSO  redshift_guess  biggest_boi_z  \
# 21           5  J1001+5944        0.374205       0.375555
#
#                      vel_disp                  radius    logmass   center_ra  \
# 21  51.016126529871144 km / s  0.5688901390254302 Mpc  11.758731  150.219894
#
#     center_dec  biggest_boi_gal_ra  ...  biggestgaltype  \
# 21   59.734655          150.167892  ...           b'SF'
#
#                                        stellar_masses  \
# 21  224    10.325436
# 227     9.442047
# 228     8.69...
#
#                                            QSOrho_min center_QSO_rho  \
# 21  250    155.41042
# Name: rho_impact, dtype: float64       0.395772
#
#    host_vs_2nd_largest                                   delta_pos_angles  \
# 21            0.130801  [16.32203968656009, 37.33424360178887, 21.0122...
#
#                                  distances_to_largest  max_dist_to_largest  \
# 21  [0.419926162047403, 0.402502113744618, 1.07011...              1.13778
#
#     min_dist         group_name
# 21  0.402502  J1001+5944_0.3742
#
# [1 rows x 24 columns]

# %%
smallbois = blue_hosts.stellar_masses.loc[21].nsmallest(len(blue_hosts.stellar_masses.loc[21])-1)
stars = [] # note: stars as in stellar mass
for index,mass in enumerate(smallbois):
    stars.append(mass)
small_bois = gal_info.loc[np.where(gal_info.mstars.isin(stars))]
small_bois_loc = SkyCoord(small_bois.gal_ra*u.deg, small_bois.gal_dec*u.deg)
QSOordinates21 = SkyCoord(gal_info.RA_QSO.loc[250]*u.deg,gal_info.DEC_QSO.loc[250]*u.deg)

# %%
plt.scatter(blue_hosts.center_ra.loc[21],blue_hosts.center_dec.loc[21],c='y',s=200,label='Center from Vel Dispersion')
plt.scatter([blue_hosts.biggest_boi_gal_ra.loc[21]],[blue_hosts.biggest_boi_gal_dec.loc[21]],c='b',s=100,label='Biggest Group Member')
plt.scatter(small_bois_loc.ra,small_bois_loc.dec,c='xkcd:Barbie Pink',label='Group Members')
plt.scatter(QSOordinates21.ra,QSOordinates21.dec,c='g',s=250,label='QSO')
plt.legend(fontsize=8)
plt.xlabel('ra (deg)')
plt.ylabel('dec (deg)')
plt.title('Isolated host in {0:s} at z={1:.4f}'.format(blue_hosts.QSO.loc[21],blue_hosts.redshift_guess.loc[21]));

# %% [markdown]
# ### Finally adding an absorption flag column to blue hosts and saving it as a csv:

# %%
# for what absorption is actually present look at isolated_blue_host_abs.txt
absorption = ['yes',
'yes',
'yes',
'no',
'no',
'yes',
'no',
'yes',
'yes',
'yes',
'no',
'yes',
'no',
'yes',
'no',
'yes',
'yes',
'yes',
'no',
'yes',
'yes',
'no',
'yes',
'yes',
'yes',
'no',
'yes',
'yes',
'yes',
'yes',
'no',
'no',
'yes',
'yes']

# %%
blue_hosts['absorption']=absorption

# %%
blue_hosts.to_csv('./blue_hosts.csv')

# %%
colormask = np.where(blue_hosts.query('center_QSO_rho < 1').absorption=='yes',1,0)

# %%
colormap = ListedColormap(['blue', 'red'])
plt.scatter(blue_hosts.query('center_QSO_rho < 1').min_dist, blue_hosts.query('center_QSO_rho < 1').center_QSO_rho, c=colormask, cmap=colormap)
cb=plt.colorbar(ticks=[0,1])
cb.set_label('Absorption Present?')
plt.xlabel('Minimum Impact Par (Mpc)')
plt.ylabel('Center to QSO Impact Par (Mpc)')
plt.title("Impact Parameter of Isolated Blue Hosts and also whether there's absorption");

# %% [markdown]
# Future work: maybe also find $\Delta \phi$ between group members and QSO.

# %%
blue_hosts
# Out:
#     party_size         QSO  redshift_guess  biggest_boi_z  \
# 0            3  J0226+0015        0.352969       0.349424
# 1            3  J0226+0015        0.297729       0.297832
# 2            3  J0809+4619        0.520972       0.520903
# 3            3  J0809+4619        0.532704       0.530117
# 6            3  J0843+4117        0.593428       0.593416
# 7            4  J0843+4117        0.579206       0.580030
# 12           4  J0914+2823        0.600128       0.599377
# 13           3  J0914+2823        0.227620       0.228207
# 14           3  J0914+2823        0.310807       0.311144
# 16           3  J0935+0204        0.353180       0.349514
# 18           3  J0935+0204        0.262358       0.262356
# 19           3  J0943+0531        0.352826       0.349870
# 21           5  J1001+5944        0.374205       0.375555
# 23           6  J1001+5944        0.304297       0.305044
# 27           4  J1016+4706        0.473917       0.476064
# 29           3  J1022+0132        0.306354       0.306360
# 30           3  J1022+0132        0.533907       0.533726
# 31           4  J1022+0132        0.478885       0.478865
# 32           3  J1022+0132        0.778404       0.778528
# 33           3  J1059+2517        0.252350       0.252359
# 36           3  J1133+0327        0.467718       0.467685
# 39           3  J1134+2555        0.682333       0.686190
# 42           4  J1233-0031        0.429621       0.429505
# 44           3  J1419+4207        0.804639       0.804798
# 45          10  J1419+4207        0.523167       0.525289
# 46           3  J1419+4207        0.451054       0.450542
# 48           3  J1419+4207        0.844714       0.845320
# 49           3  J1437+5045        0.129863       0.129806
# 51           3  J1437+5045        0.507022       0.506984
# 52           3  J1437+5045        0.568278       0.568027
# 55           3  J1437+5045        0.662283       0.665170
# 56           5  J1553+3548        0.514815       0.515695
# 58           3  J1553+3548        0.341723       0.341716
# 60           3  J1555+3628        0.473317       0.473284
#
#                      vel_disp                   radius    logmass   center_ra  \
# 0   434.27875527748006 km / s  0.47554728663794493 Mpc  13.541019   36.550684
# 1    82.10966884351586 km / s   0.5454572807064169 Mpc  12.153837   36.534892
# 2   170.96243529961782 km / s   0.4460492822060432 Mpc  12.703472  122.302953
# 3    64.25117503448554 km / s   0.2425109703073517 Mpc  11.588781  122.316879
# 6    587.4728056954765 km / s   0.4896173058758222 Mpc  13.816120  130.961451
# 7     741.130979407261 km / s   0.6160718164183764 Mpc  14.117709  130.958811
# 12   210.4741084339208 km / s   0.4752470294288141 Mpc  12.911604  138.652848
# 13  240.27501987336456 km / s    0.251752369433876 Mpc  12.750678  138.694743
# 14   561.4205251140576 km / s  0.44549509983645014 Mpc  13.735707  138.688157
# 16   822.0843914831577 km / s   0.3401254094698518 Mpc  13.949760  143.823312
# 18  0.9201273020458339 km / s  0.15471800895647564 Mpc   7.705524  143.846282
# 19   655.9707824671318 km / s   0.2454700801315825 Mpc  13.612055  145.877258
# 21  51.016126529871144 km / s   0.5688901390254302 Mpc  11.758731  150.219894
# 23   240.0750518356186 km / s  0.26566115918382893 Mpc  12.773310  150.260730
# 27  455.71223330553465 km / s    0.440068504891036 Mpc  13.549189  154.105707
# 29  49.823274227083125 km / s  0.20176510050950291 Mpc  11.287998  155.560027
# 30   92.17046631377323 km / s   0.4821948323634357 Mpc  12.200694  155.590649
# 31   96.22351642437532 km / s   0.4256346803900126 Mpc  12.183887  155.594120
# 32  211.36513504003636 km / s  0.32625040460533994 Mpc  12.751905  155.604510
# 33  132.99019217487657 km / s  0.18648443087653868 Mpc  12.106569  165.011136
# 36  17.193235872562784 km / s  0.37628639216676374 Mpc  10.634521  165.014694
# 39   37.14685365127767 km / s  0.07194602335718978 Mpc  10.585139  165.014694
# 42   61.12559304011862 km / s  0.30678702056675555 Mpc  11.647571  188.276403
# 44   78.79438613759665 km / s    0.500663331857725 Mpc  12.080824  214.760092
# 45   448.4756817567214 km / s   0.8004768097057685 Mpc  13.795114  214.774654
# 46   547.3745465285758 km / s   0.5152001720735138 Mpc  13.776833  214.780044
# 48   663.2489729066789 km / s    0.467671855190145 Mpc  13.901582  214.792490
# 49  30.811119942886368 km / s   0.4409059561591224 Mpc  11.210049  219.351719
# 51  20.137643239144477 km / s  0.44537453376787595 Mpc  10.845030  219.324709
# 52  453.73883226033576 km / s  0.20575947679303447 Mpc  13.215259  219.334858
# 55                 0.0 km / s  0.29146352500080314 Mpc       -inf  219.392225
# 56   244.6061982685603 km / s   0.5849852395413537 Mpc  13.132367  238.258513
# 58  3.3539954627102717 km / s  0.08672124371833087 Mpc   8.577538  238.247110
# 60   16.61013805659391 km / s  0.38276978095884173 Mpc  10.611972  238.749078
#
#     center_dec  biggest_boi_gal_ra  ...  \
# 0     0.249508           36.550751  ...
# 1     0.259185           36.510059  ...
# 2    46.331768          122.327316  ...
# 3    46.342665          122.326057  ...
# 6    41.332694          130.936050  ...
# 7    41.305138          130.938828  ...
# 12   28.389869          138.656982  ...
# 13   28.413870          138.675736  ...
# 14   28.386134          138.689453  ...
# 16    2.086358          143.810104  ...
# 18    2.084222          143.846161  ...
# 19    5.530814          145.862518  ...
# 21   59.734655          150.167892  ...
# 23   59.723170          150.258621  ...
# 27   47.130616          154.127747  ...
# 29    1.518050          155.560059  ...
# 30    1.555789          155.590790  ...
# 31    1.527781          155.593658  ...
# 32    1.494220          155.606110  ...
# 33   25.246529          164.992950  ...
# 36    3.455419          165.014694  ...
# 39   25.905016          165.014694  ...
# 42   -0.543167          188.295471  ...
# 44   42.120558          214.740555  ...
# 45   42.141278          214.781998  ...
# 46   42.126707          214.778671  ...
# 48   42.133696          214.789032  ...
# 49   50.763601          219.354141  ...
# 51   50.764800          219.323227  ...
# 52   50.758727          219.329620  ...
# 55   50.778816          219.391067  ...
# 56   35.815565          238.263519  ...
# 58   35.783810          238.250778  ...
# 60   36.464416          238.778564  ...
#
#                                        stellar_masses  \
# 0   0     8.405740
# 10    8.493776
# 12    9.237293
# N...
# 1   1     10.386827
# 3      8.162347
# 18     8.84550...
# 2   30    8.682405
# 39    8.705125
# 49    9.479523
# N...
# 3   40     9.084104
# 44     9.159035
# 47    11.03056...
# 6   69     10.393711
# 90      8.713455
# 117     9.35...
# 7   74     10.899514
# 84      9.720776
# 97      9.87...
# 12  137    10.191614
# 138     9.490131
# 141    11.04...
# 13  149    11.202757
# 153     9.994957
# 163     9.86...
# 14  150     8.158745
# 152    11.682953
# 154     8.63...
# 16  176    11.811457
# 181    10.423237
# 197     9.15...
# 18  187     9.837980
# 196    10.530492
# 198     9.46...
# 19  207    10.893807
# 209     8.866977
# 210     9.32...
# 21  224    10.325436
# 227     9.442047
# 228     8.69...
# 23  237     9.155372
# 239     8.476067
# 243    10.09...
# 27  281     9.496166
# 299     9.483203
# 307     9.17...
# 29  328     8.463286
# 333     8.426620
# 334    10.71...
# 30  340     9.478680
# 352     8.594994
# 353    11.55...
# 31  350     8.635663
# 361    11.788202
# 363     8.58...
# 32  360     9.481286
# 366     8.782385
# 368    11.89...
# 33  405    9.403366
# 410    8.820952
# 417    8.81656...
# 36  451    10.365916
# 456     9.418045
# 467     9.42...
# 39  482    10.482227
# 491     9.215330
# 499     9.65...
# 42  540     9.709296
# 543     9.479102
# 544     9.23...
# 44  577    11.653812
# 591    10.017536
# 593     9.63...
# 45  581     8.485661
# 594     8.889313
# 595     9.46...
# 46  596     9.317186
# 602    10.559592
# 621     9.02...
# 48  613    10.209694
# 618     8.701060
# 625     9.39...
# 49  643    8.595956
# 666    9.615144
# 703    8.21489...
# 51  652    11.283110
# 654     9.650446
# 682     9.39...
# 52  656    10.812742
# 659     9.398558
# 663     8.94...
# 55  691    10.937677
# 692     9.743704
# 693     9.21...
# 56  709     9.223935
# 717     9.004314
# 724     8.76...
# 58  715    8.036078
# 716    8.246564
# 719    9.99781...
# 60  752     9.103222
# 755     9.481825
# 763    11.15...
#
#                                            QSOrho_min center_QSO_rho  \
# 0   12    212.200456
# Name: rho_impact, dtype: float64       0.239549
# 1   18    309.147669
# Name: rho_impact, dtype: float64       0.417939
# 2   30    226.299365
# Name: rho_impact, dtype: float64       0.355759
# 3   40    572.241914
# Name: rho_impact, dtype: float64       0.691767
# 6   90    899.830087
# Name: rho_impact, dtype: float64       0.936858
# 7   101    375.549683
# Name: rho_impact, dtype: flo...       0.254085
# 12  141    303.581866
# Name: rho_impact, dtype: flo...       0.340196
# 13  149    315.719541
# Name: rho_impact, dtype: flo...       0.433909
# 14  150    314.999336
# Name: rho_impact, dtype: flo...       0.311530
# 16  176    360.920261
# Name: rho_impact, dtype: flo...       0.287324
# 18  187    141.302724
# Name: rho_impact, dtype: flo...       0.366572
# 19  210    102.839092
# Name: rho_impact, dtype: flo...       0.129033
# 21  250    155.41042
# Name: rho_impact, dtype: float64       0.395772
# 23   245    36.91707
# Name: rho_impact, dtype: float64       0.235986
# 27  299    381.322851
# Name: rho_impact, dtype: flo...       0.443457
# 29  334    467.49673
# Name: rho_impact, dtype: float64       0.470172
# 30  340    452.192237
# Name: rho_impact, dtype: flo...       0.485326
# 31  363    363.752931
# Name: rho_impact, dtype: flo...       0.408274
# 32  360    775.332921
# Name: rho_impact, dtype: flo...       1.407118
# 33  410    590.532778
# Name: rho_impact, dtype: flo...       0.612114
# 36  467    414.320135
# Name: rho_impact, dtype: flo...     181.995406
# 39  499    376.80286
# Name: rho_impact, dtype: float64     205.609506
# 42  544    238.806524
# Name: rho_impact, dtype: flo...       0.405474
# 44  593    691.657879
# Name: rho_impact, dtype: flo...       0.716621
# 45  612    387.89927
# Name: rho_impact, dtype: float64       0.407706
# 46  621    126.689806
# Name: rho_impact, dtype: flo...       0.207898
# 48  613    122.414144
# Name: rho_impact, dtype: flo...       0.113081
# 49  666    261.495566
# Name: rho_impact, dtype: flo...       0.042494
# 51  682    447.361324
# Name: rho_impact, dtype: flo...       0.493722
# 52  663    201.203053
# Name: rho_impact, dtype: flo...       0.402484
# 55  693    556.818694
# Name: rho_impact, dtype: flo...       0.644814
# 56  724    478.405737
# Name: rho_impact, dtype: flo...       0.284146
# 58  719    478.854259
# Name: rho_impact, dtype: flo...       0.554419
# 60  755    483.318838
# Name: rho_impact, dtype: flo...       0.482911
#
#    host_vs_2nd_largest                                   delta_pos_angles  \
# 0             0.180502                                [99.01205342892192]
# 1             0.028752                               [39.148057129619794]
# 2             0.168113                                [3.020439645889155]
# 3             0.013442                               [19.517995533384124]
# 6             0.091290                                 [7.04908661386051]
# 7             0.142579  [34.469395857192154, 0.419501258109392, 34.049...
# 12            0.138638  [1.087181911866935, 162.8818972573213, 161.794...
# 13            0.061973                                [34.65042406359683]
# 14            0.000895                               [141.75255020516497]
# 16            0.040905                               [28.629875810130883]
# 18            0.202996                                [173.1349631084515]
# 19            0.026936                               [10.414009960728663]
# 21            0.130801  [16.32203968656009, 37.33424360178887, 21.0122...
# 23            0.249290  [6.357915227418857, 135.5786464428034, 129.220...
# 27            0.045630  [29.24033559467901, 35.53241578567355, 6.29208...
# 29            0.005660                               [105.03490421949314]
# 30            0.008382                               [30.670812982823065]
# 31            0.004996  [12.188796830053207, 15.742959079386349, 27.93...
# 32            0.003827                                [102.6656325846827]
# 33            0.261568                               [10.138840526550318]
# 36            0.113903                                            [180.0]
# 39            0.147314                                                 []
# 42            0.322758  [54.121410558133846, 60.721537590140485, 6.600...
# 44            0.023106                               [101.97514682702563]
# 45            0.143845  [69.7808226295212, 23.879466814941082, 22.2853...
# 46            0.057226                               [34.024012473484504]
# 48            0.153806                               [105.90687606352859]
# 49            0.095678                               [102.16850547107373]
# 51            0.023299                                [93.06800666730273]
# 52            0.038532                                [36.64958498303616]
# 55            0.063977                               [2.9761279923270365]
# 56            0.104965  [11.151789846325528, 28.091695917874688, 16.93...
# 58            0.017731                                [29.85626308013238]
# 60            0.021202                                [9.569737410408152]
#
#                                  distances_to_largest max_dist_to_largest  \
# 0           [0.8305753859114637, 0.35119949973112213]            0.830575
# 1           [0.36014567540456316, 1.0909145614128337]            1.090915
# 2            [0.8920985644120765, 0.3404412353302686]            0.892099
# 3             [0.485021940614694, 0.4146818889551109]            0.485022
# 6            [0.4510282355157211, 0.9792346117516444]            0.979235
# 7   [1.2321436328367528, 0.7674014062515297, 0.887...            1.232144
# 12  [0.24839155529185483, 0.24707328742404375, 0.7...            0.710290
# 13          [0.22337841272957862, 0.5035047388677485]            0.503505
# 14           [0.2331941078251866, 0.6960798245296334]            0.696080
# 16          [0.22679497563174308, 0.6802508189397036]            0.680251
# 18         [0.2509522439927861, 0.058825625670392345]            0.250952
# 19                          [0.3780458660766428, nan]                 NaN
# 21  [0.419926162047403, 0.402502113744618, 1.07011...            1.137780
# 23  [0.21613190330213936, 0.06764841351091602, 0.3...            0.354968
# 27  [0.8801370097820692, 0.5400325513879486, 0.461...            0.880137
# 29        [0.4017617720469416, 0.0066218251038681775]            0.401762
# 30           [0.9643896647268684, 0.0691551792787617]            0.964390
# 31  [0.633489798714044, 0.8512693607800231, 0.8099...            0.851269
# 32          [0.6293312626792726, 0.08278379964556176]            0.629331
# 33         [0.36530902035486224, 0.37296886175306904]            0.372969
# 36         [0.46590942404445523, 0.28666336028906936]            0.465909
# 39       [0.0013494874448325667, 0.14389204671437955]            0.143892
# 42  [0.5992507359161022, 0.5577724612288787, 0.613...            0.613574
# 44           [0.5918906202936364, 0.6941374452470978]            0.694137
# 45  [1.598924204430042, 0.332392976626347, 0.42643...            1.600954
# 46           [1.0304003441470275, 0.6631369036865545]            1.030400
# 48          [0.06382947751925189, 0.9158331774191497]            0.915833
# 49           [0.5289470464492412, 0.6028144769536727]            0.602814
# 51          [0.11585732398011704, 0.8770032459178845]            0.877003
# 52         [0.41047442298877634, 0.41151895358606894]            0.411519
# 55          [0.20638638213927635, 0.5829270500016063]            0.582927
# 56  [0.9877341316709336, 0.9881879063866529, 0.076...            1.169970
# 58         [0.17344248743666174, 0.06835446593101771]            0.173442
# 60           [0.7655395619176519, 0.6673205417772562]            0.765540
#
#     min_dist         group_name absorption
# 0   0.351199   J0226+0015_0.353        yes
# 1   0.360146  J0226+0015_0.2977        yes
# 2   0.340441   J0809+4619_0.521        yes
# 3   0.414682  J0809+4619_0.5327         no
# 6   0.451028  J0843+4117_0.5934         no
# 7   0.767401  J0843+4117_0.5792        yes
# 12  0.247073  J0914+2823_0.6001         no
# 13  0.223378  J0914+2823_0.2276        yes
# 14  0.233194  J0914+2823_0.3108        yes
# 16  0.226795  J0935+0204_0.3532        yes
# 18  0.058826  J0935+0204_0.2624         no
# 19       NaN  J0943+0531_0.3528        yes
# 21  0.402502  J1001+5944_0.3742         no
# 23  0.067648  J1001+5944_0.3043        yes
# 27  0.461629  J1016+4706_0.4739         no
# 29  0.006622  J1022+0132_0.3064        yes
# 30  0.069155  J1022+0132_0.5339        yes
# 31  0.633490  J1022+0132_0.4789        yes
# 32  0.082784  J1022+0132_0.7784         no
# 33  0.365309  J1059+2517_0.2524        yes
# 36  0.286663  J1133+0327_0.4677        yes
# 39  0.001349  J1134+2555_0.6823         no
# 42  0.557772  J1233-0031_0.4296        yes
# 44  0.591891  J1419+4207_0.8046        yes
# 45  0.332393  J1419+4207_0.5232        yes
# 46  0.663137  J1419+4207_0.4511         no
# 48  0.063829  J1419+4207_0.8447        yes
# 49  0.528947  J1437+5045_0.1299        yes
# 51  0.115857   J1437+5045_0.507        yes
# 52  0.410474  J1437+5045_0.5683        yes
# 55  0.206386  J1437+5045_0.6623         no
# 56  0.076566  J1553+3548_0.5148         no
# 58  0.068354  J1553+3548_0.3417        yes
# 60  0.667321  J1555+3628_0.4733        yes
#
# [34 rows x 25 columns]

# %%
gal_info
# Out:
#                       specfile                       id      OBJECT  \
# 0     J022601.51+001532.5.fits  J022601.51+001532.5._03  J0226+0015
# 1     J022602.41+001536.6.fits  J022602.41+001536.6._01  J0226+0015
# 2     J022606.98+001451.4.fits  J022606.98+001451.4._02  J0226+0015
# 3     J022607.08+001612.7.fits  J022607.08+001612.7._01  J0226+0015
# 4     J022608.02+001427.2.fits  J022608.02+001427.2._03  J0226+0015
# 5     J022609.11+001513.1.fits  J022609.11+001513.1._01  J0226+0015
# 6     J022610.26+001603.7.fits  J022610.26+001603.7._01  J0226+0015
# 7     J022610.44+001514.0.fits  J022610.44+001514.0._03  J0226+0015
# 8     J022611.06+001323.6.fits  J022611.06+001323.6._02  J0226+0015
# 9     J022611.40+001341.3.fits  J022611.40+001341.3._01  J0226+0015
# 10    J022612.15+001357.5.fits  J022612.15+001357.5._03  J0226+0015
# 11    J022612.18+001407.3.fits  J022612.18+001407.3._01  J0226+0015
# 12    J022612.18+001506.0.fits  J022612.18+001506.0._01  J0226+0015
# 13    J022613.33+001358.7.fits  J022613.33+001358.7._01  J0226+0015
# 14    J022614.39+001620.4.fits  J022614.39+001620.4._02  J0226+0015
# 15    J022614.58+001351.4.fits  J022614.58+001351.4._03  J0226+0015
# 16    J022616.82+001624.7.fits  J022616.82+001624.7._01  J0226+0015
# 17    J022617.54+001834.5.fits  J022617.54+001834.5._01  J0226+0015
# 18    J022617.99+001447.5.fits  J022617.99+001447.5._02  J0226+0015
# 19    J022619.99+001435.3.fits  J022619.99+001435.3._02  J0226+0015
# 20    J022622.00+001642.3.fits  J022622.00+001642.3._01  J0226+0015
# 21    J080852.41+461747.5.fits  J080852.41+461747.5._03  J0809+4619
# 22    J080859.67+462048.0.fits  J080859.67+462048.0._04  J0809+4619
# 23    J080901.07+462153.4.fits  J080901.07+462153.4._03  J0809+4619
# 24    J080901.51+462029.7.fits  J080901.51+462029.7._02  J0809+4619
# 25    J080901.64+461903.3.fits  J080901.64+461903.3._01  J0809+4619
# 26    J080903.95+462000.0.fits  J080903.95+462000.0._03  J0809+4619
# 27    J080903.96+461952.5.fits  J080903.96+461952.5._02  J0809+4619
# 28    J080903.97+461911.9.fits  J080903.97+461911.9._04  J0809+4619
# 29    J080904.33+461854.9.fits  J080904.33+461854.9._01  J0809+4619
# ...                        ...                      ...         ...
# 980                        NaN  J155509.59+362922.1._11         NaN
# 981                        NaN  J155514.02+362644.5._11         NaN
# 982                        NaN  J234506.77-010129.5._04         NaN
# 983                        NaN                      -99         NaN
# 984                        NaN                      -99         NaN
# 985                        NaN                      -99         NaN
# 986                        NaN                      -99         NaN
# 987                        NaN                      -99         NaN
# 988                        NaN                      -99         NaN
# 989                        NaN                      -99         NaN
# 990                        NaN                      -99         NaN
# 991                        NaN                      -99         NaN
# 992                        NaN                      -99         NaN
# 993                        NaN                      -99         NaN
# 994                        NaN                      -99         NaN
# 995                        NaN                      -99         NaN
# 996                        NaN                      -99         NaN
# 997                        NaN                      -99         NaN
# 998                        NaN                      -99         NaN
# 999                        NaN                      -99         NaN
# 1000                       NaN                      -99         NaN
# 1001                       NaN                      -99         NaN
# 1002                       NaN                      -99         NaN
# 1003                       NaN                      -99         NaN
# 1004                       NaN                      -99         NaN
# 1005                       NaN                      -99         NaN
# 1006                       NaN                      -99         NaN
# 1007                       NaN                      -99         NaN
# 1008                       NaN                      -99         NaN
# 1009                       NaN                      -99         NaN
#
#               cgm_name_x      gal_ra    gal_dec         z      OII_flux  \
# 0     J0226+0015_271_194   36.506302   0.259040  0.352715           NaN
# 1     J0226+0015_272_181   36.510059   0.260170  0.297832           NaN
# 2     J0226+0015_251_119   36.529079   0.247620  0.384662  4.200000e-17
# 3     J0226+0015_291_119   36.529518   0.270200  0.299556           NaN
# 4     J0226+0015_237_115   36.533401   0.240880  0.506584  4.100000e-17
# 5      J0226+0015_258_82   36.537972   0.253650  0.496565           NaN
# 6      J0226+0015_298_72   36.542740   0.267700  0.334506           NaN
# 7      J0226+0015_255_62   36.543480   0.253900  0.507057  5.970000e-17
# 8     J0226+0015_202_136   36.546089   0.223230  0.474940           NaN
# 9     J0226+0015_203_118   36.547489   0.228130  0.365194  1.560000e-17
# 10     J0226+0015_201_99   36.550621   0.232630  0.353237  1.340000e-16
# 11     J0226+0015_203_89   36.550770   0.235350  0.473967  9.970000e-17
# 12     J0226+0015_235_42   36.550751   0.251680  0.349424  1.190000e-16
# 13     J0226+0015_191_93   36.555531   0.232970  0.609547  1.270000e-16
# 14     J0226+0015_359_51   36.559978   0.272330  0.361854  1.210000e-16
# 15     J0226+0015_179_98   36.560749   0.230950  0.292878           NaN
# 16      J0226+0015_33_65   36.570080   0.273540  0.559038  4.770000e-17
# 17     J0226+0015_14_190   36.573071   0.309580  0.399510           NaN
# 18     J0226+0015_129_68   36.574951   0.246520  0.297620           NaN
# 19     J0226+0015_123_99   36.583271   0.243150  0.456666  1.480000e-16
# 20     J0226+0015_57_134   36.591679   0.278430  0.228233           NaN
# 21    J0809+4619_239_190  122.218391  46.296539  0.190097           NaN
# 22    J0809+4619_313_120  122.248619  46.346668  0.201800  9.370000e-17
# 23    J0809+4619_334_165  122.254440  46.364830  0.222970           NaN
# 24     J0809+4619_313_94  122.256302  46.341572  0.141552           NaN
# 25     J0809+4619_252_71  122.256821  46.317589  0.147291           NaN
# 26     J0809+4619_308_55  122.266472  46.333321  0.339670           NaN
# 27     J0809+4619_302_51  122.266487  46.331249  0.645031  1.110000e-16
# 28     J0809+4619_252_45  122.266533  46.319969  0.489935  3.190000e-17
# 29     J0809+4619_232_50  122.268059  46.315262  0.074531           NaN
# ...                  ...         ...        ...       ...           ...
# 980                  NaN         NaN        NaN       NaN           NaN
# 981                  NaN         NaN        NaN       NaN           NaN
# 982                  NaN         NaN        NaN       NaN           NaN
# 983                  NaN         NaN        NaN       NaN           NaN
# 984                  NaN         NaN        NaN       NaN           NaN
# 985                  NaN         NaN        NaN       NaN           NaN
# 986                  NaN         NaN        NaN       NaN           NaN
# 987                  NaN         NaN        NaN       NaN           NaN
# 988                  NaN         NaN        NaN       NaN           NaN
# 989                  NaN         NaN        NaN       NaN           NaN
# 990                  NaN         NaN        NaN       NaN           NaN
# 991                  NaN         NaN        NaN       NaN           NaN
# 992                  NaN         NaN        NaN       NaN           NaN
# 993                  NaN         NaN        NaN       NaN           NaN
# 994                  NaN         NaN        NaN       NaN           NaN
# 995                  NaN         NaN        NaN       NaN           NaN
# 996                  NaN         NaN        NaN       NaN           NaN
# 997                  NaN         NaN        NaN       NaN           NaN
# 998                  NaN         NaN        NaN       NaN           NaN
# 999                  NaN         NaN        NaN       NaN           NaN
# 1000                 NaN         NaN        NaN       NaN           NaN
# 1001                 NaN         NaN        NaN       NaN           NaN
# 1002                 NaN         NaN        NaN       NaN           NaN
# 1003                 NaN         NaN        NaN       NaN           NaN
# 1004                 NaN         NaN        NaN       NaN           NaN
# 1005                 NaN         NaN        NaN       NaN           NaN
# 1006                 NaN         NaN        NaN       NaN           NaN
# 1007                 NaN         NaN        NaN       NaN           NaN
# 1008                 NaN         NaN        NaN       NaN           NaN
# 1009                 NaN         NaN        NaN       NaN           NaN
#
#       OII_flux_sig  OII_LQ  ...     SFR_photo  match_ang_separation  \
# 0              NaN     NaN  ...      1.894698          9.669706e-09
# 1              NaN     NaN  ...      0.228083          8.892883e-09
# 2     5.280000e-18     1.0  ...     35.912585          2.318738e-09
# 3              NaN     NaN  ...      0.655333          3.608513e-09
# 4     3.290000e-18     1.0  ...      2.769872          2.426000e-08
# 5              NaN     0.0  ...    200.273364          5.085844e-10
# 6              NaN     NaN  ...      2.298427          2.211278e-08
# 7     3.550000e-18     1.0  ...    103.043924          8.002066e-10
# 8              NaN     NaN  ...     80.712525          1.119949e-09
# 9     3.340000e-18     1.0  ...      3.730040          9.407547e-09
# 10    5.040000e-18     1.0  ...      2.148002          4.745002e-09
# 11    2.940000e-18     1.0  ...     17.114651          7.230282e-09
# 12    5.900000e-18     1.0  ...      6.982141          8.811267e-09
# 13    2.900000e-18     1.0  ...     77.683789          4.796022e-09
# 14    3.540000e-18     1.0  ...     12.480931          2.758794e-08
# 15             NaN     0.0  ...      0.292358          3.395609e-09
# 16    1.400000e-18     1.0  ...     26.626880          1.661358e-08
# 17             NaN     NaN  ...      6.280477          2.081283e-08
# 18             NaN     NaN  ...      2.205100          2.512793e-08
# 19    4.540000e-18     1.0  ...      6.821023          2.088290e-09
# 20             NaN     NaN  ...    123.762158          5.662589e-09
# 21             NaN     NaN  ...      9.124538          4.806822e-07
# 22    1.120000e-17     1.0  ...      3.162514          4.623350e-09
# 23             NaN     NaN  ...     16.524429          4.074605e-07
# 24             NaN     NaN  ...      2.286176          2.662032e-06
# 25             NaN     NaN  ...      0.462883          1.767483e-06
# 26             NaN     NaN  ...      1.021457          2.815457e-06
# 27    1.420000e-18     1.0  ...     18.791693          9.009260e-07
# 28    1.540000e-18     0.0  ...      3.646939          6.586337e-07
# 29             NaN     NaN  ...      0.101186          2.245355e-06
# ...            ...     ...  ...           ...                   ...
# 980            NaN     NaN  ...      0.708656          1.212828e-06
# 981            NaN     NaN  ...     69.909668          3.106232e-06
# 982            NaN     NaN  ...  58299.667738          3.177416e-08
# 983            NaN     NaN  ...      0.208176         -9.900000e+01
# 984            NaN     NaN  ...      0.725298         -9.900000e+01
# 985            NaN     NaN  ...      0.702405         -9.900000e+01
# 986            NaN     NaN  ...      1.125435         -9.900000e+01
# 987            NaN     NaN  ...     -0.446832         -9.900000e+01
# 988            NaN     NaN  ...     -0.789126         -9.900000e+01
# 989            NaN     NaN  ...     -0.256846         -9.900000e+01
# 990            NaN     NaN  ...      0.851067         -9.900000e+01
# 991            NaN     NaN  ...      0.691398         -9.900000e+01
# 992            NaN     NaN  ...      0.333200         -9.900000e+01
# 993            NaN     NaN  ...      0.095484         -9.900000e+01
# 994            NaN     NaN  ...      0.521077         -9.900000e+01
# 995            NaN     NaN  ...      0.824612         -9.900000e+01
# 996            NaN     NaN  ...      0.604136         -9.900000e+01
# 997            NaN     NaN  ...      0.705485         -9.900000e+01
# 998            NaN     NaN  ...     -0.945213         -9.900000e+01
# 999            NaN     NaN  ...     -0.998131         -9.900000e+01
# 1000           NaN     NaN  ...     -0.464684         -9.900000e+01
# 1001           NaN     NaN  ...     -1.497051         -9.900000e+01
# 1002           NaN     NaN  ...     -0.123772         -9.900000e+01
# 1003           NaN     NaN  ...     -0.541823         -9.900000e+01
# 1004           NaN     NaN  ...     -0.201249         -9.900000e+01
# 1005           NaN     NaN  ...     -0.983146         -9.900000e+01
# 1006           NaN     NaN  ...     -0.993554         -9.900000e+01
# 1007           NaN     NaN  ...     -0.860572         -9.900000e+01
# 1008           NaN     NaN  ...     -0.128418         -9.900000e+01
# 1009           NaN     NaN  ...     -0.185173         -9.900000e+01
#
#        logmhalo           rvir   rho_rvir          sSFR     Z_R23  \
# 0     10.860650      96.313076  10.328094     -6.511042       NaN
# 1     11.908800     224.417288   3.685016    -10.158744       NaN
# 2     11.572587     162.502477   3.948948     26.077379       NaN
# 3     10.735680      91.083501   5.984588     -7.507014       NaN
# 4     11.114763     105.099983   6.943187     -6.099805       NaN
# 5     12.403701     284.542106   1.805834    189.507753       NaN
# 6     10.858702      97.481408   3.636310     -6.112105       NaN
# 7     12.101398     224.049729   1.766947     92.505079  8.733941
# 8     11.709037     169.399713   4.913714     70.686793       NaN
# 9     11.204854     124.288799   4.963415     -5.395472  8.968619
# 10    10.901966      99.377845   5.085181     -6.345773       NaN
# 11    11.317662     125.528153   4.347684      7.817859  8.817902
# 12    11.254542     130.629229   1.624449     -2.255151  8.797051
# 13    11.775558     163.364388   3.933047     67.604712  8.667289
# 14    11.334052     137.582031   1.914676      3.089776  8.794375
# 15    11.558122     172.117249   2.582089     -9.572636       NaN
# 16    11.606622     148.146717   2.934786     16.816995  8.605120
# 17    11.386777     139.409090   7.556740     -3.193431       NaN
# 18    11.052070     116.292208   2.658370     -6.640401       NaN
# 19    11.444785     140.037117   4.233206     -2.735012  8.661784
# 20    11.935786     242.097100   2.091300    113.323272       NaN
# 21    11.348776     159.227472   3.907776     -0.420409       NaN
# 22    11.142832     134.623216   3.063817     -5.945706  8.507528
# 23    11.555634     181.608816   3.361497      6.616006       NaN
# 24    10.810767     109.841948   2.195794     -6.143044       NaN
# 25    10.641857      96.003490   1.964307     -7.581939       NaN
# 26    10.800575      92.868550   2.970985     -7.261690       NaN
# 27    11.359547     116.149208   3.116750      9.485209  8.682401
# 28    10.975054      95.468237   2.953298     -4.940741       NaN
# 29    10.525382      93.738194   0.779298     -7.733068       NaN
# ...         ...            ...        ...           ...       ...
# 980   11.293840     162.897493   0.943557     -8.794709       NaN
# 981   11.631035     165.196880   5.889300     59.992268       NaN
# 982   20.893160  165562.882708   0.006710  58286.659150       NaN
# 983  -99.000000      68.577299   0.675487    -10.293240       NaN
# 984  -99.000000      82.809187   1.512069    -10.089568       NaN
# 985  -99.000000      49.454318   2.968480     -9.459387       NaN
# 986  -99.000000      75.263767   1.230621     -9.511765       NaN
# 987  -99.000000      67.609985   0.480352    -10.968410       NaN
# 988  -99.000000      83.480704   0.585471    -11.641289       NaN
# 989  -99.000000      29.983142   3.238878     -9.873951       NaN
# 990  -99.000000      92.081452   0.386185    -10.100627       NaN
# 991  -99.000000      69.751580   0.475700     -9.857761       NaN
# 992  -99.000000      50.943468   1.104852     -9.767860       NaN
# 993  -99.000000      47.014961   2.034639     -9.970582       NaN
# 994  -99.000000      38.571876   2.755057     -9.315151       NaN
# 995  -99.000000      56.566036   0.960343     -9.512972       NaN
# 996  -99.000000      63.199883   0.470676     -9.950876       NaN
# 997  -99.000000      51.972250   0.413443     -9.477701       NaN
# 998  -99.000000      94.560802   1.220810    -11.968440       NaN
# 999  -99.000000      83.381034   1.008746    -11.820960       NaN
# 1000 -99.000000     114.700640   0.149884    -11.712802       NaN
# 1001 -99.000000     100.918424   1.543257    -12.475855       NaN
# 1002 -99.000000      52.149789   0.453018    -10.360922       NaN
# 1003 -99.000000      24.258662   5.348980     -9.519569       NaN
# 1004 -99.000000      38.532246   2.795031     -9.789841       NaN
# 1005 -99.000000      19.480723   7.219171     -9.659050       NaN
# 1006 -99.000000      24.986746   1.660345    -10.072767       NaN
# 1007 -99.000000      13.404533   3.224185     -9.048450       NaN
# 1008 -99.000000      50.526188   0.783317    -10.058545       NaN
# 1009 -99.000000      41.312489   1.204424     -9.867217       NaN
#
#          Z_R23_flag  Z_Flag  friends_group
# 0              none    O3N2              0
# 1              none     NaN              1
# 2              none      N2              2
# 3              none      N2              1
# 4              none     NaN              3
# 5              none     NaN              4
# 6              none     NaN              5
# 7     upper w/ mass     R23              3
# 8              none     NaN              6
# 9     upper w/ mass     R23              7
# 10             none     NaN              0
# 11    upper w/ mass     R23              6
# 12    upper w/ mass     R23              0
# 13    upper w/ mass     R23              8
# 14    upper w/ mass     R23              7
# 15             none     NaN              9
# 16    upper w/ mass     R23             10
# 17             none    O3N2             11
# 18             none     NaN              1
# 19    upper w/ mass     R23             12
# 20             none    O3N2             13
# 21             none     NaN             14
# 22            upper     R23             15
# 23             none     NaN             16
# 24             none     NaN             17
# 25             none     NaN             18
# 26             none     NaN             19
# 27    upper w/ mass     R23             20
# 28             none     NaN             21
# 29             none     NaN             22
# ...             ...     ...            ...
# 980            none     NaN            682
# 981            none     NaN            683
# 982            none     NaN            684
# 983            none     NaN            685
# 984            none     NaN            686
# 985            none     NaN            687
# 986            none     NaN            688
# 987            none     NaN            689
# 988            none     NaN            690
# 989            none     NaN            691
# 990            none     NaN            692
# 991            none     NaN            693
# 992            none     NaN            694
# 993            none     NaN            695
# 994            none     NaN            696
# 995            none     NaN            697
# 996            none     NaN            698
# 997            none     NaN            699
# 998            none     NaN            700
# 999            none     NaN            701
# 1000           none     NaN            702
# 1001           none     NaN            703
# 1002           none     NaN            704
# 1003           none     NaN            705
# 1004           none     NaN            706
# 1005           none     NaN            707
# 1006           none     NaN            708
# 1007           none     NaN            709
# 1008           none     NaN            710
# 1009           none     NaN            711
#
# [1010 rows x 189 columns]
